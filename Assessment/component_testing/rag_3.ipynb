# %%
from copy import deepcopy
from pathlib import Path
import os
import re
from copy import deepcopy
from pathlib import Path
from llama_index.core import Settings
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_parse import LlamaParse
from llama_index.core.schema import TextNode
from typing import Optional

# %%
import nest_asyncio

nest_asyncio.apply()

# %% [markdown]
# ## Setting Up LlamaIndex and OpenAI Models
#
# In this section, we initialize the `Settings` for LlamaIndex with the OpenAI embedding and language models. We use the `OpenAIEmbedding` model for embeddings and the `OpenAI` model for language processing.

# %%
OPENAI_API_KEY = os.getenv('PERSONAL_OAI_API_KEY') 
LLAMA_API_KEY = os.getenv('LLAMA_CLOUD_API_KEY')

# %%
embed_model = OpenAIEmbedding(model="text-embedding-3-large", api_key=OPENAI_API_KEY)
llm = OpenAI(model="gpt-4o-mini", api_key=OPENAI_API_KEY)

Settings.embed_model = embed_model
Settings.llm = llm

# %%
parser = LlamaParse(
    result_type="markdown",
    use_vendor_multimodal_model=True,
    vendor_multimodal_model_name="openai-gpt-4o-mini",
    vendor_multimodal_api_key=OPENAI_API_KEY,
    verbose=True,
    fast_mode=True,
    num_workers=8,
)

# %%
if os.path.exists("input\WSQ - Project Management with Generative AI (GenAI) - v3.pdf"):
    print("File exists")
# Out:
# File exists

# %%
print(f"Parsing slide deck...")
md_json_objs = parser.get_json_result("input\WSQ - Project Management with Generative AI (GenAI) - v3.pdf")
md_json_list = md_json_objs[0]["pages"]
# Out:
# Parsing slide deck...
# Started parsing the file under job_id ded5715c-130d-4631-b814-f6bfbb644d48

# %%
print(md_json_list[1]["text"])
# Out:
#                         Digital Attendance
# ●
#    It is mandatory for you to take both AM and
#    PM digital attendance especially for WSQ
#    courses.                                                           Scan with Singpass appto log in
# ●  The trainer or administrator will show you
#    the digital attendance QR code generated
#    from TPG.
# ●  Please scan the QR code from your                                      Singpass
#    Singpass App and submit your
#    attendance.
#                                                                                               2
#                      This material belongs to Tertiary Infotech Pte Ltd (UEN: 20120096W). All Rights Reserved

# %%
print(md_json_list[1].keys())
# Out:
# dict_keys(['page', 'text', 'images', 'charts', 'items', 'status', 'links', 'width', 'height', 'triggeredAutoMode', 'structuredData', 'noStructuredContent', 'noTextContent'])

# %%
image_dicts = parser.get_images(md_json_objs, download_path="data_images")
# Out:
# > Image for page 1: [{'name': 'img_p0_3.png', 'height': 137, 'width': 300, 'x': 15.348425687999999, 'y': 219.125947956912, 'original_width': 300, 'original_height': 137, 'ocr': [{'x': 106, 'y': 34, 'w': 116, 'h': 24, 'confidence': '0.9842973394927044', 'text': 'SINGAPORE'}, {'x': 21, 'y': 47, 'w': 64, 'h': 40, 'confidence': '0.9812295739401005', 'text': 'WS'}, {'x': 106, 'y': 54, 'w': 194, 'h': 26, 'confidence': '0.4937106920834399', 'text': 'WorkforCE SKILL8'}, {'x': 106, 'y': 75, 'w': 159, 'h': 24, 'confidence': '0.6521510474818355', 'text': 'QUALIFICATIONS'}]}, {'name': 'img_p0_4.png', 'height': 80, 'width': 350, 'x': 82.51181366399999, 'y': 311.43105327288, 'original_width': 350, 'original_height': 80, 'ocr': [{'x': 2, 'y': 6, 'w': 348, 'h': 74, 'confidence': '0.37336243117196827', 'text': 'Umfmtech'}]}, {'name': 'img_p0_5.png', 'height': 400, 'width': 400, 'x': 12.000000384, 'y': 306.91363186847997, 'original_width': 400, 'original_height
# > Image for page 12: []
# > Image for page 13: []
# > Image for page 14: []
# > Image for page 15: []
# > Image for page 16: []
# > Image for page 17: []
# > Image for page 18: [{'name': 'img_p17_3.png', 'height': 338, 'width': 322, 'x': 277.21851280799996, 'y': 187.90945483199997, 'original_width': 322, 'original_height': 338}]
# > Image for page 19: [{'name': 'img_p18_1.png', 'height': 979, 'width': 1514, 'x': 0.000908464596, 'y': 0, 'original_width': 1514, 'original_height': 979}]
# > Image for page 20: []
# > Image for page 21: []
# > Image for page 22: [{'name': 'img_p21_1.png', 'height': 1560, 'width': 1576, 'x': 6.000000192, 'y': 51.84448984800002, 'original_width': 1576, 'original_height': 1560}]
# > Image for page 23: [{'name': 'img_p22_1.png', 'height': 1366, 'width': 2048, 'x': 60.297246023999996, 'y': 207.74604995495997, 'original_width': 2048, 'original_height': 1366}, {'name': 'img_p22_2.png', 'height': 1363, 'width': 2048, 'x': 383.15546501688, 'y': 207.93957358319997, 'original_width': 2048, 'original_height': 1363}]
# > Image for page 24: []
# > Image for page 25: []
# > Image for page 26: [{'name': 'img_p25_1.png', 'height': 1310, 'width': 1304, 'x': 399.20670568799994, 'y': 54.85630096799997, 'original_width': 1304, 'original_height': 1310, 'ocr': [{'x': 339, 'y': 129, 'w': 98, 'h': 42, 'confidence': '0.49454352259635925', 'text': 'W E'}, {'x': 490, 'y': 126, 'w': 136, 'h': 48, 'confidence': '0.7958294293167675', 'text': 'A R E'}, {'x': 677, 'y': 125, 'w': 276, 'h': 48, 'confidence': '0.6999501440386255', 'text': 'H | R | N G'}, {'x': 377, 'y': 187, 'w': 542, 'h': 176, 'confidence': '0.9984649822686127', 'text': 'Project'}, {'x': 324, 'y': 341, 'w': 654, 'h': 188, 'confidence': '0.9982432746670968', 'text': 'Manager'}, {'x': 440, 'y': 1035, 'w': 414, 'h': 51, 'confidence': '0.5605104649567285', 'text': 'Send Your portfolio'}, {'x': 862, 'y': 1046, 'w': 46, 'h': 30, 'confidence': '0.9926017442008015', 'text': 'to'}, {'x': 478, 'y': 1111, 'w': 393, 'h': 38, 'confidence': '0.7119195844451576', 'text': 'WWW reallygreatsite com'}]}]
# > Image for page 27: []
# > Image for page 28: [{'name': 'img_p27_1.png', 'height': 396, 'width': 436, 'x': 12.000000384, 'y': 63.844490232, 'original_width': 436, 'original_height': 396, 'ocr': [{'x': 181, 'y': 51, 'w': 65, 'h': 28, 'confidence': '0.9999079296498026', 'text': 'Scope'}, {'x': 173, 'y': 211, 'w': 83, 'h': 36, 'confidence': '0.9999340810884622', 'text': 'Quality'}, {'x': 54, 'y': 298, 'w': 56, 'h': 26, 'confidence': '0.9999469518661499', 'text': 'Time'}, {'x': 330, 'y': 308, 'w': 50, 'h': 26, 'confidence': '0.9999452829360962', 'text': 'Cost'}]}]
 37, 'confidence': '0.9999834362317136', 'text': 'Meetings'}, {'x': 954, 'y': 298, 'w': 88, 'h': 33, 'confidence': '0.9999970713016556', 'text': 'updates'}, {'x': 124, 'y': 330, 'w': 218, 'h': 26, 'confidence': '0.9785565638058588', 'text': 'Project communications'}, {'x': 124, 'y': 358, 'w': 272, 'h': 26, 'confidence': '0.9991803729968455', 'text': 'Quality control measurements'}, {'x': 123, 'y': 383, 'w': 139, 'h': 28, 'confidence': '0.8964942482797305', 'text': 'Quality reports'}, {'x': 124, 'y': 412, 'w': 266, 'h': 24, 'confidence': '0.9040055918774369', 'text': 'Requirements documentation'}, {'x': 124, 'y': 438, 'w': 112, 'h': 29, 'confidence': '0.7601685620023415', 'text': 'Risk register'}, {'x': 124, 'y': 466, 'w': 102, 'h': 26, 'confidence': '0.999981597096498', 'text': 'Risk report'}, { ...
# > Image for page 366: []
# > Image for page 367: []
# > Image for page 368: []
# > Image for page 369: []
# > Image for page 370: []
# > Image for page 371: []
# > Image for page 372: []
# > Image for page 373: []
# > Image for page 374: []
# > Image for page 375: []
# > Image for page 376: [{'name': 'img_p375_2.png', 'height': 343, 'width': 346, 'x': 241.360243944, 'y': 144.83070542198402, 'original_width': 346, 'original_height': 343}]
# > Image for page 377: [{'name': 'img_p376_2.png', 'height': 200, 'width': 200, 'x': 253.52758685303996, 'y': 136.32287837808, 'original_width': 200, 'original_height': 200}]
# > Image for page 378: []
# > Image for page 379: []

# %%
from llama_index.core.schema import TextNode
from typing import Optional

# %%
# get pages loaded through llamaparse
import re


def get_page_number(file_name):
    match = re.search(r"-page-(\d+)\.jpg$", str(file_name))
    if match:
        return int(match.group(1))
    return 0


def _get_sorted_image_files(image_dir):
    """Get image files sorted by page."""
    raw_files = [f for f in list(Path(image_dir).iterdir()) if f.is_file()]
    sorted_files = sorted(raw_files, key=get_page_number)
    return sorted_files

# %%
from copy import deepcopy
from pathlib import Path


# attach image metadata to the text nodes
def get_text_nodes(json_dicts, image_dir=None):
    """Split docs into nodes, by separator."""
    nodes = []

    image_files = _get_sorted_image_files(image_dir) if image_dir is not None else None
    md_texts = [d["text"] for d in json_dicts]

    for idx, md_text in enumerate(md_texts):
        chunk_metadata = {"page_num": idx + 1}
        # Check if an image exists for the current index
        if idx < len(image_files):
            chunk_metadata["image_path"] = str(image_files[idx])
        else:
            chunk_metadata["image_path"] = None  # No image available for this page
        
        # if image_files is not None:
        #     image_file = image_files[idx]
        #     chunk_metadata["image_path"] = str(image_file)
        chunk_metadata["parsed_text_markdown"] = md_text
        node = TextNode(
            text="",
            metadata=chunk_metadata,
        )
        nodes.append(node)

    return nodes

# %%
# this will split into pages
text_nodes = get_text_nodes(md_json_list, image_dir="data_images")

# %%
print(text_nodes[10].get_content(metadata_mode="all"))
# Out:
# page_num: 11
# image_path: data_images\ded5715c-130d-4631-b814-f6bfbb644d48-img_p115_1.png
# parsed_text_markdown:                                  Course Outline
# Topic 1: Project Initiation and Planning with GenAI (K2, A1)
#  ●    Initiating a Project - Overview
#  ●    Develop Project Charter
#  ●    Identify Stakeholders
#  ●    Develop Project Management Plan
#  ●    Plan Stakeholder Engagement
#  ●    Plan Scope Management
#  ●    Plan Schedule Management
#  ●    Plan Cost Management
#  ●    Plan Quality Management
#  ●    Plan Resource Management
#  ●    Plan Communications Management
#  ●    Plan Risk Management
#  ●    Plan Risk Responses
#  ●    Plan Procurement Management                                                                       11
#                          This material belongs to Tertiary Infotech Pte Ltd (UEN: 20120096W). All Rights Reserved

# %%
import os
from llama_index.core import (
    StorageContext,
    SummaryIndex,
    load_index_from_storage,
)

if not os.path.exists("storage_nodes_summary"):
    index = SummaryIndex(text_nodes)
    # save index to disk
    index.set_index_id("summary_index")
    index.storage_context.persist("./storage_nodes_summary")
else:
    # rebuild storage context
    storage_context = StorageContext.from_defaults(persist_dir="storage_nodes_summary")
    # load index
    index = load_index_from_storage(storage_context, index_id="summary_index")

# %%
from pydantic import BaseModel
from openai import OpenAI
from docx import Document
from typing import Dict, List
from llama_parse import LlamaParse
import nest_asyncio
import os
import json

# API access to llama-cloud
LLAMA_API_KEY = os.getenv("LLAMA_CLOUD_API_KEY")

# Using OpenAI API for embeddings/llms
OPENAI_API_KEY = os.getenv("TERTIARY_INFOTECH_API_KEY")

# Initialize the OpenAI client
client = OpenAI(api_key=OPENAI_API_KEY)

# Define the Pydantic model for structured data extraction
class KnowledgeStatement(BaseModel):
    id: str
    text: str


class AbilityStatement(BaseModel):
    id: str
    text: str


class Topic(BaseModel):
    name: str
    subtopics: List[str]
    tsc_knowledges: List[KnowledgeStatement]
    tsc_abilities: List[AbilityStatement]


class LearningUnit(BaseModel):
    name: str
    topics: List[Topic]
    learning_outcome: str


class AssessmentMethod(BaseModel):
    code: str
    duration: str


class FacilitatorGuideExtraction(BaseModel):
    course_title: str
    tsc_proficiency_level: str
    learning_units: List[LearningUnit]
    assessments: List[AssessmentMethod]  # New field for assessments

# Function to load FG document content using LlamaParse
def parse_with_llamaparse(file_path: str) -> str:
    """
    Parses the FG document using LlamaParse to preprocess its content.

    Args:
        file_path (str): Path to the document.

    Returns:
        str: Preprocessed content of the document as text.
    """

    parser = LlamaParse(
        api_key=LLAMA_API_KEY,
        result_type="markdown",
        show_progress=True,
        verbose=True,
        num_workers=8
    )

    result = parser.get_json_result(file_path)
    return result

# Function to load FG document content
def load_fg_document(file_path: str) -> str:
    """
    Reads the content of a Word document.

    Args:
        file_path (str): Path to the document.

    Returns:
        str: The document's text content.
    """
    doc = Document(file_path)
    return "\n".join([para.text for para in doc.paragraphs])

# Function to extract structured data from FG document
def extract_fg_data(preprocessed_content: str) -> FacilitatorGuideExtraction:
    """
    Extracts relevant information from the FG document using GPT and Pydantic.

    Args:
        preprocessed_content (str): Preprocessed text content of the FG document.

    Returns:
        FacilitatorGuideExtraction: Extracted and validated data.
    """
    completion = client.beta.chat.completions.parse(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": (
                    """You are an expert at structured data extraction. Extract the following details from the FG Document:
                    - Course Title
                    - TSC Proficiency Level
                    - Learning Units (LUs):
                        * Name of the Learning Unit
                        * Topics in the Learning Unit:
                            - Name of the Topic
                            - Description of the Topic (bullet points or sub-topics)
                            - Full Knowledge Statements associated with the topic, including their identifiers and text (e.g., K1: Range of AI applications)
                            - Full Ability Statements associated with the topic, including their identifiers and text (e.g., A1: Analyze algorithms in the AI applications)
                        * Learning Outcome (LO) for each Learning Unit
                    - Assessment Types and Durations:
                        * Extract assessment types and their durations in the format:
                          {"code": "WA-SAQ", "duration": "1 hr"}
                          {"code": "PP", "duration": "0.5 hr"}
                          {"code": "CS", "duration": "30 mins"}
                        * Interpret abbreviations of assessment methods to their correct types (e.g., "WA-SAQ," "PP," "CS").
                        * Include total durations if mentioned.

                    Return the output in a JSON format that matches the schema provided:
                    {
                        "course_title": "string",
                        "tsc_proficiency_level": "string",
                        "learning_units": [
                            {
                                "name": "string",
                                "topics": [
                                    {
                                        "name": "string",
                                        "subtopics": ["string"],
                                        "tsc_knowledges": [
                                            {"id": "string", "text": "string"}
                                        ],
                                        "tsc_abilities": [
                                            {"id": "string", "text": "string"}
                                        ]
                                    }
                                ],
                                "learning_outcome": "string"
                            }
                        ],
                        "assessments": [
                            {"code": "string", "duration": "string"}
                        ]
                    }
                    """
                ),
            },
            {"role": "user", "content": preprocessed_content},
        ],
        response_format=FacilitatorGuideExtraction,
    )

    return completion.choices[0].message.parsed

# Main Execution
if __name__ == "__main__":
    # Path to the FG document
    file_path = "input/FG_TGS-2024049183 - Project Management with Generative AI (GenAI)_v1.docx"
    
    # Parse document content using LlamaParse
    try:
        parsed_content = parse_with_llamaparse(file_path)
        print("Preprocessed Content:")
        print(json.dumps(parsed_content, indent=4))
    except Exception as e:
        print(f"Error during LlamaParse parsing: {e}")
        exit(1)

    # Extract and validate structured data using OpenAI and Pydantic
    try:
        extracted_data = extract_fg_data(json.dumps(parsed_content))
        print("Structured Data:")
        print(extracted_data)
    except Exception as e:
        print(f"Error during OpenAI extraction: {e}")
# Out:
# Started parsing the file under job_id ab8037a6-c891-42da-8ed5-b06ea54f6a3b
# Preprocessed Content:
# [
#     {
#         "pages": [
#             {
#                 "page": 1,
#                 "text": "             Facilitator Guide\n                         For\n\nProject Management with Generative AI (GenAI)\n\n          TGS Ref No: TGS-2024049183\n\n                   Conducted by\n         TERTIARY INFOTECH PTE. LTD\n\n                UEN: 201200696W\n\n                    Version 1.0",
#                 "md": "# Facilitator Guide\n\n# For\n\n# Project Management with Generative AI (GenAI)\n\nTGS Ref No: TGS-2024049183\n\n# Conducted by\n\nTERTIARY INFOTECH PTE. LTD\n\nUEN: 201200696W\n\nVersion 1.0",
#                 "images": [
#                     {
#                         "name": "img_p0_1.png",
#                         "height": 278,
#                         "width": 277,
#                         "x": 225.25,
#                         "y": 157.90076377952806,
#                         "original_width": 277,
#                         "original_height": 278
#                     }
#                 ],
#                 "charts": [],
#                 "items": [
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Facilitator Guide",
#                         "md": "# Facilitator Guide",
#                         "bBox": {
#                             "x": 218,
#                             "y": 309.89,
#                             "w": 157.68,
#                             "h": 20
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "For",
#                         "md": "# For",
#                         "bBox": {
#                             "x": 286,
#                             "y": 349.89,
#                             "w": 22.53,
#                             "h": 14
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Project Management with Generative AI (GenAI)",
#                         "md": "# Project Management with Generative AI (GenAI)",
#                         "bBox": {
#                             "x": 139,
#                             "y": 381.89,
#                             "w": 316.95,
#                             "h": 14
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "TGS Ref No: TGS-2024049183",
#                         "md": "TGS Ref No: TGS-2024049183",
#                         "bBox": {
#                             "x": 199,
#                             "y": 413.89,
#                             "w": 197.33,
#                             "h": 14
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Conducted by",
#                         "md": "# Conducted by",
#                         "bBox": {
#                             "x": 251,
#                             "y": 445.89,
#                             "w": 93.18,
#                             "h": 14
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "TERTIARY INFOTECH PTE. LTD\n\nUEN: 201200696W\n\nVersion 1.0",
#                         "md": "TERTIARY INFOTECH PTE. LTD\n\nUEN: 201200696W\n\nVersion 1.0",
#                         "bBox": {
#                             "x": 192,
#                             "y": 461.89,
#                             "w": 211.3,
#                             "h": 79
#                         }
#                     }
#                 ],
#                 "status": "OK",
#                 "links": [],
#                 "width": 595.303937007874,
#                 "height": 841.889763779528,
#                 "triggeredAutoMode": false,
#                 "structuredData": null,
#                 "noStructuredContent": false,
#                 "noTextContent": false
#             },
#             {
#                 "page": 2,
#                 "text": "Table of Content\n2.      Course Overview                                                                                                                                4\n3.      Learning Outcomes                                                                                                                              5\n4.      Lesson Plan and Instructional Methods                                                                                                          7\n    Instructional methods                                                                                                                              7\n    Lesson Plan                                                                                                                                        7\n        Day 1                                                                                                                                          7\n        Day 2                                                                                                                                        10\n5.      Structure & Duration of Training & Assessment                                                                                                13\n6.      Reference                                                                                                                                    14\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by\nTertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication,\ndistribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for\npurposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage2 of 14",
#                 "md": "# Table of Content\n\n1. Course Overview ................................................................................. 4\n2. Learning Outcomes ........................................................................ 5\n3. Lesson Plan and Instructional Methods ................................................. 7\n4. - Instructional methods ................................................................ 7\n- Lesson Plan ......................................................................................... 7\n\nStructure & Duration of Training & Assessment ................................ 13\n5. Reference ............................................................................................... 14\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.",
#                 "images": [],
#                 "charts": [],
#                 "items": [
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Table of Content",
#                         "md": "# Table of Content",
#                         "bBox": {
#                             "x": 36,
#                             "y": 69.89,
#                             "w": 126.13,
#                             "h": 16
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "1. Course Overview ................................................................................. 4\n2. Learning Outcomes ........................................................................ 5\n3. Lesson Plan and Instructional Methods ................................................. 7\n4. - Instructional methods ................................................................ 7\n- Lesson Plan ......................................................................................... 7\n\nStructure & Duration of Training & Assessment ................................ 13\n5. Reference ............................................................................................... 14\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.",
#                         "md": "1. Course Overview ................................................................................. 4\n2. Learning Outcomes ........................................................................ 5\n3. Lesson Plan and Instructional Methods ................................................. 7\n4. - Instructional methods ................................................................ 7\n- Lesson Plan ......................................................................................... 7\n\nStructure & Duration of Training & Assessment ................................ 13\n5. Reference ............................................................................................... 14\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.",
#                         "bBox": {
#                             "x": 36,
#                             "y": 106.89,
#                             "w": 523,
#                             "h": 664
#                         }
#                     }
#                 ],
#                 "status": "OK",
#                 "links": [],
#                 "width": 595.303937007874,
#                 "height": 841.889763779528,
#                 "triggeredAutoMode": false,
#                 "structuredData": null,
#                 "noStructuredContent": false,
#                 "noTextContent": false
#             },
#             {
#                 "page": 3,
#                 "text": "1. DOCUMENT VERSION CONTROL RECORD\n                                                Effective Date of                            Summary of Included\n       Version Number                                  Release                                         Changes                                     Author\n    1.0                                   26 Sep 2024                                 First version                                        Tertiary Infotech\n  Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by\n  Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication,\n  distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for\n  purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\n  Page3 of 14",
#                 "md": "# DOCUMENT VERSION CONTROL RECORD\n\n|Version Number|Effective Date of Release|Summary of Included Changes|Author|\n|---|---|---|---|\n|1.0|26 Sep 2024|First version|Tertiary Infotech|\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 3 of 14",
#                 "images": [],
#                 "charts": [],
#                 "items": [
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "DOCUMENT VERSION CONTROL RECORD",
#                         "md": "# DOCUMENT VERSION CONTROL RECORD",
#                         "bBox": {
#                             "x": 0,
#                             "y": 0,
#                             "w": 595.3,
#                             "h": 841.89
#                         }
#                     },
#                     {
#                         "type": "table",
#                         "rows": [
#                             [
#                                 "Version Number",
#                                 "Effective Date of Release",
#                                 "Summary of Included Changes",
#                                 "Author"
#                             ],
#                             [
#                                 "1.0",
#                                 "26 Sep 2024",
#                                 "First version",
#                                 "Tertiary Infotech"
#                             ]
#                         ],
#                         "md": "|Version Number|Effective Date of Release|Summary of Included Changes|Author|\n|---|---|---|---|\n|1.0|26 Sep 2024|First version|Tertiary Infotech|",
#                         "isPerfectTable": true,
#                         "csv": "\"Version Number\",\"Effective Date of Release\",\"Summary of Included Changes\",\"Author\"\n\"1.0\",\"26 Sep 2024\",\"First version\",\"Tertiary Infotech\"",
#                         "bBox": {
#                             "x": 36,
#                             "y": 132.89,
#                             "w": 513.39,
#                             "h": 638
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 3 of 14",
#                         "md": "Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 3 of 14",
#                         "bBox": {
#                             "x": 36,
#                             "y": 152.89,
#                             "w": 513.39,
#                             "h": 618
#                         }
#                     }
#                 ],
#                 "status": "OK",
#                 "links": [],
#                 "width": 595.303937007874,
#                 "height": 841.889763779528,
#                 "triggeredAutoMode": false,
#                 "structuredData": null,
#                 "noStructuredContent": false,
#                 "noTextContent": false
#             },
#             {
#                 "page": 4,
#                 "text": "2. Course Overview\n   Skills Framework                                    BEV\n   TSC Category                                        Project Management\n   TSC Code                                            BEV-BIN-5021-1.1-1\n   TSC Title                                           Project Management\n   TSC Description                                     Lead project teams to implement project master plans\n   TSC Proficiency Level                               5\n   Recommended Class Size                              10\n   TSC Abilities and Knowledge\n   TSC Abilities:\n   A1: Develop project parameters according to business requirements\n   A2: Advise staff in resolving challenges during project delivery\n   A3: Anticipate potential risks to project delivery\n   A4: Devise risk mitigation measures to ensure project success\n   TSC Knowledge:\n   K1: Project risk management\n   K2: Building project master plans\n   K3: Optimisation of resource and project budgets\n\n   Resources Required\n      \u25cf Standard training equipment \u2013 computer, overhead projector, etc.\n      \u25cf Flip chart papers and markers\n      \u25cf Paper tape / Blu Tac\n   Abbreviations\n      \u25cf Learner\u2019s Guide (LG)\n      \u25cf Facilitator\u2019s Guide (FG)\n      \u25cf Assessment Plan (AP)\n      \u25cf Lesson Plan (LP)\n  Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by\n  Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication,\n  distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for\n  purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\n  Page4 of 14",
#                 "md": "# 2. Course Overview\n\n|Skills Framework|BEV|\n|---|---|\n|TSC Category|Project Management|\n|TSC Code|BEV-BIN-5021-1.1-1|\n|TSC Title|Project Management|\n|TSC Description|Lead project teams to implement project master plans|\n|TSC Proficiency Level|5|\n|Recommended Class Size|10|\n\n# TSC Abilities and Knowledge\n\n# TSC Abilities:\n\n- A1: Develop project parameters according to business requirements\n- A2: Advise staff in resolving challenges during project delivery\n- A3: Anticipate potential risks to project delivery\n- A4: Devise risk mitigation measures to ensure project success\n\n# TSC Knowledge:\n\n- K1: Project risk management\n- K2: Building project master plans\n- K3: Optimisation of resource and project budgets\n\n# Resources Required\n\n- Standard training equipment \u2013 computer, overhead projector, etc.\n- Flip chart papers and markers\n- Paper tape / Blu Tac\n\n# Abbreviations\n\n- Learner\u2019s Guide (LG)\n- Facilitator\u2019s Guide (FG)\n- Assessment Plan (AP)\n- Lesson Plan (LP)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 4 of 14",
#                 "images": [],
#                 "charts": [],
#                 "items": [
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "2. Course Overview",
#                         "md": "# 2. Course Overview",
#                         "bBox": {
#                             "x": 31,
#                             "y": 69.89,
#                             "w": 132.24,
#                             "h": 14
#                         }
#                     },
#                     {
#                         "type": "table",
#                         "rows": [
#                             [
#                                 "Skills Framework",
#                                 "BEV"
#                             ],
#                             [
#                                 "TSC Category",
#                                 "Project Management"
#                             ],
#                             [
#                                 "TSC Code",
#                                 "BEV-BIN-5021-1.1-1"
#                             ],
#                             [
#                                 "TSC Title",
#                                 "Project Management"
#                             ],
#                             [
#                                 "TSC Description",
#                                 "Lead project teams to implement project master plans"
#                             ],
#                             [
#                                 "TSC Proficiency Level",
#                                 "5"
#                             ],
#                             [
#                                 "Recommended Class Size",
#                                 "10"
#                             ]
#                         ],
#                         "md": "|Skills Framework|BEV|\n|---|---|\n|TSC Category|Project Management|\n|TSC Code|BEV-BIN-5021-1.1-1|\n|TSC Title|Project Management|\n|TSC Description|Lead project teams to implement project master plans|\n|TSC Proficiency Level|5|\n|Recommended Class Size|10|",
#                         "isPerfectTable": true,
#                         "csv": "\"Skills Framework\",\"BEV\"\n\"TSC Category\",\"Project Management\"\n\"TSC Code\",\"BEV-BIN-5021-1.1-1\"\n\"TSC Title\",\"Project Management\"\n\"TSC Description\",\"Lead project teams to implement project master plans\"\n\"TSC Proficiency Level\",\"5\"\n\"Recommended Class Size\",\"10\"",
#                         "bBox": {
#                             "x": 41,
#                             "y": 100.89,
#                             "w": 441.6,
#                             "h": 100
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "TSC Abilities and Knowledge",
#                         "md": "# TSC Abilities and Knowledge",
#                         "bBox": {
#                             "x": 41,
#                             "y": 207.89,
#                             "w": 152.04,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "TSC Abilities:",
#                         "md": "# TSC Abilities:",
#                         "bBox": {
#                             "x": 41,
#                             "y": 226.89,
#                             "w": 71.42,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "- A1: Develop project parameters according to business requirements\n- A2: Advise staff in resolving challenges during project delivery\n- A3: Anticipate potential risks to project delivery\n- A4: Devise risk mitigation measures to ensure project success",
#                         "md": "- A1: Develop project parameters according to business requirements\n- A2: Advise staff in resolving challenges during project delivery\n- A3: Anticipate potential risks to project delivery\n- A4: Devise risk mitigation measures to ensure project success",
#                         "bBox": {
#                             "x": 41,
#                             "y": 238.89,
#                             "w": 331.31,
#                             "h": 50
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "TSC Knowledge:",
#                         "md": "# TSC Knowledge:",
#                         "bBox": {
#                             "x": 41,
#                             "y": 304.89,
#                             "w": 87.33,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "- K1: Project risk management\n- K2: Building project master plans\n- K3: Optimisation of resource and project budgets",
#                         "md": "- K1: Project risk management\n- K2: Building project master plans\n- K3: Optimisation of resource and project budgets",
#                         "bBox": {
#                             "x": 41,
#                             "y": 317.89,
#                             "w": 238.44,
#                             "h": 36
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Resources Required",
#                         "md": "# Resources Required",
#                         "bBox": {
#                             "x": 41,
#                             "y": 368.89,
#                             "w": 106.89,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "- Standard training equipment \u2013 computer, overhead projector, etc.\n- Flip chart papers and markers\n- Paper tape / Blu Tac",
#                         "md": "- Standard training equipment \u2013 computer, overhead projector, etc.\n- Flip chart papers and markers\n- Paper tape / Blu Tac",
#                         "bBox": {
#                             "x": 0,
#                             "y": 0,
#                             "w": 595.3,
#                             "h": 841.89
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Abbreviations",
#                         "md": "# Abbreviations",
#                         "bBox": {
#                             "x": 41,
#                             "y": 443.89,
#                             "w": 73.28,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "- Learner\u2019s Guide (LG)\n- Facilitator\u2019s Guide (FG)\n- Assessment Plan (AP)\n- Lesson Plan (LP)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 4 of 14",
#                         "md": "- Learner\u2019s Guide (LG)\n- Facilitator\u2019s Guide (FG)\n- Assessment Plan (AP)\n- Lesson Plan (LP)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 4 of 14",
#                         "bBox": {
#                             "x": 36,
#                             "y": 735.89,
#                             "w": 513.39,
#                             "h": 35
#                         }
#                     }
#                 ],
#                 "status": "OK",
#                 "links": [],
#                 "width": 595.303937007874,
#                 "height": 841.889763779528,
#                 "triggeredAutoMode": false,
#                 "structuredData": null,
#                 "noStructuredContent": false,
#                 "noTextContent": false
#             },
#             {
#                 "page": 5,
#                 "text": "        3. Learning Outcomes\n                Learning Units (LUs)                              Mapping of Knowledge and Abilities Statements\n\nLU1: Project Initiation and\nPlanning with GenAI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTopics:\nTopic 1 Project Initiation and Planning with GenAI (K2, A1)\n\u25cf Initiating a Project - Overview\n\u25cf Develop Project Charter\n\u25cf Identify Stakeholders\n\u25cf Develop Project Management Plan\n\u25cf Plan Stakeholder Engagement\n\u25cf Plan Scope Management\n\u25cf Plan Schedule Management\n\u25cf Plan Cost Management\n\u25cf Plan Quality Management\n\u25cf Plan Resource Management\n\u25cf Plan Communications Management\n\u25cf Plan Risk Management\n\u25cf Plan Risk Responses\n\u25cf Plan Procurement Management\n\n                                                       LO1 \u2013 Develop project parameters with GenAI according to\n                                                       business requirements\n\n                                                       K2: Building project master plans\n                                                       A1: Develop project parameters according to business\n                                                       requirements\n          LU2: Project Execution and                   Topics:\n          Delivery with GenAI                          Topic 2 Project Execution and Delivery with GenAI (K3, A2)\n                                                       \u25cf Direct and Manage Project Work\n                                                       \u25cf Manage Project Knowledge\n                                                       \u25cf Manage Stakeholder Engagement\n                                                       \u25cf Manage Quality\n                                                       \u25cf Acquire Resources\n                                                       \u25cf Manage Team\n          Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by\n          Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication,\n          distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for\n          purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\n          Page5 of 14",
#                 "md": "# 3. Learning Outcomes\n\n# Learning Units (LUs)\n\n# LU1: Project Initiation and Planning with GenAI\n\n# Topics:\n\n- Topic 1 Project Initiation and Planning with GenAI (K2, A1)\n\nLO1 \u2013 Develop project parameters with GenAI according to business requirements\n\nK2: Building project master plans\n\nA1: Develop project parameters according to business requirements\n\n# LU2: Project Execution and Delivery with GenAI\n\n# Topics:\n\n- Topic 2 Project Execution and Delivery with GenAI (K3, A2)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 5 of 14",
#                 "images": [],
#                 "charts": [],
#                 "items": [
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "3. Learning Outcomes",
#                         "md": "# 3. Learning Outcomes",
#                         "bBox": {
#                             "x": 31,
#                             "y": 83.89,
#                             "w": 149.25,
#                             "h": 14
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Learning Units (LUs)",
#                         "md": "# Learning Units (LUs)",
#                         "bBox": {
#                             "x": 58,
#                             "y": 114.89,
#                             "w": 108.1,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "LU1: Project Initiation and Planning with GenAI",
#                         "md": "# LU1: Project Initiation and Planning with GenAI",
#                         "bBox": {
#                             "x": 36,
#                             "y": 140.89,
#                             "w": 125.87,
#                             "h": 24
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Topics:",
#                         "md": "# Topics:",
#                         "bBox": {
#                             "x": 199,
#                             "y": 140.89,
#                             "w": 35.44,
#                             "h": 441
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "- Topic 1 Project Initiation and Planning with GenAI (K2, A1)\n\nLO1 \u2013 Develop project parameters with GenAI according to business requirements\n\nK2: Building project master plans\n\nA1: Develop project parameters according to business requirements",
#                         "md": "- Topic 1 Project Initiation and Planning with GenAI (K2, A1)\n\nLO1 \u2013 Develop project parameters with GenAI according to business requirements\n\nK2: Building project master plans\n\nA1: Develop project parameters according to business requirements",
#                         "bBox": {
#                             "x": 36,
#                             "y": 153.89,
#                             "w": 467.78,
#                             "h": 415
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "LU2: Project Execution and Delivery with GenAI",
#                         "md": "# LU2: Project Execution and Delivery with GenAI",
#                         "bBox": {
#                             "x": 36,
#                             "y": 570.89,
#                             "w": 133.29,
#                             "h": 24
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Topics:",
#                         "md": "# Topics:",
#                         "bBox": {
#                             "x": 199,
#                             "y": 140.89,
#                             "w": 35.44,
#                             "h": 441
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "- Topic 2 Project Execution and Delivery with GenAI (K3, A2)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 5 of 14",
#                         "md": "- Topic 2 Project Execution and Delivery with GenAI (K3, A2)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 5 of 14",
#                         "bBox": {
#                             "x": 36,
#                             "y": 583.89,
#                             "w": 513.39,
#                             "h": 187
#                         }
#                     }
#                 ],
#                 "status": "OK",
#                 "links": [],
#                 "width": 595.303937007874,
#                 "height": 841.889763779528,
#                 "triggeredAutoMode": false,
#                 "structuredData": null,
#                 "noStructuredContent": false,
#                 "noTextContent": false
#             },
#             {
#                 "page": 6,
#                 "text": "                                                          \u25cf Manage Communications\n\n                                                          LO2 \u2013 Resolve project delivery challenges by optimizing resource\n                                                          and project budgets with GenAI.\n\n\n\nLU3: Manage Project Risks\nwith GenAI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nK3: Optimisation of resource and project budgets\nA2: Advise staff in resolving challenges during project delivery\nTopics:\nTopic 3 Manage Project Risks with GenAI (K1, A3, A4)\n\u25cf Implement Risk Responses\n\u25cf Conduct Procurements\n\u25cf Monitor and Control Project Work\n\u25cf Perform Integrated Change Control\n\u25cf Monitor Stakeholder Engagement\n\u25cf Validate Scope\n\u25cf Control Scope\n\u25cf Control Schedule\n\u25cf Control Costs\n\u25cf Control Quality\n\u25cf Control Resources\n\u25cf Monitor Communications\n\u25cf Monitor Risks\n\u25cf Close Project or Phase\n\n                                                          LO3 \u2013 Anticipate and devise risk mitigation measures with GenAI\n                                                          to ensure project success\n\n                                                          K1: Project risk management\n                                                          A3: Anticipate potential risks to project delivery\n                                                          A4: Devise risk mitigation measures to ensure project success\n          Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by\n          Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication,\n          distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for\n          purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\n          Page6 of 14",
#                 "md": "# Manage Communications\n\n# LO2 \u2013 Resolve project delivery challenges by optimizing resource and project budgets with GenAI.\n\n# LU3: Manage Project Risks with GenAI\n\n# K3: Optimisation of resource and project budgets\n\n# A2: Advise staff in resolving challenges during project delivery\n\n# Topics:\n\n- Topic 3 Manage Project Risks with GenAI (K1, A3, A4)\n- Implement Risk Responses\n- Conduct Procurements\n- Monitor and Control Project Work\n- Perform Integrated Change Control\n- Monitor Stakeholder Engagement\n- Validate Scope\n- Control Scope\n- Control Schedule\n- Control Costs\n- Control Quality\n- Control Resources\n- Monitor Communications\n- Monitor Risks\n- Close Project or Phase\n\n# LO3 \u2013 Anticipate and devise risk mitigation measures with GenAI to ensure project success\n\n# K1: Project risk management\n\n# A3: Anticipate potential risks to project delivery\n\n# A4: Devise risk mitigation measures to ensure project success\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 6 of 14",
#                 "images": [],
#                 "charts": [],
#                 "items": [
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Manage Communications",
#                         "md": "# Manage Communications",
#                         "bBox": {
#                             "x": 0,
#                             "y": 0,
#                             "w": 595.3,
#                             "h": 841.89
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "LO2 \u2013 Resolve project delivery challenges by optimizing resource and project budgets with GenAI.",
#                         "md": "# LO2 \u2013 Resolve project delivery challenges by optimizing resource and project budgets with GenAI.",
#                         "bBox": {
#                             "x": 36,
#                             "y": 104.89,
#                             "w": 481.43,
#                             "h": 87
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "LU3: Manage Project Risks with GenAI",
#                         "md": "# LU3: Manage Project Risks with GenAI",
#                         "bBox": {
#                             "x": 36,
#                             "y": 167.89,
#                             "w": 133.25,
#                             "h": 24
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "K3: Optimisation of resource and project budgets",
#                         "md": "# K3: Optimisation of resource and project budgets",
#                         "bBox": {
#                             "x": 199,
#                             "y": 141.89,
#                             "w": 238.44,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "A2: Advise staff in resolving challenges during project delivery",
#                         "md": "# A2: Advise staff in resolving challenges during project delivery",
#                         "bBox": {
#                             "x": 199,
#                             "y": 154.89,
#                             "w": 301.31,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Topics:",
#                         "md": "# Topics:",
#                         "bBox": {
#                             "x": 199,
#                             "y": 167.89,
#                             "w": 35.44,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "- Topic 3 Manage Project Risks with GenAI (K1, A3, A4)\n- Implement Risk Responses\n- Conduct Procurements\n- Monitor and Control Project Work\n- Perform Integrated Change Control\n- Monitor Stakeholder Engagement\n- Validate Scope\n- Control Scope\n- Control Schedule\n- Control Costs\n- Control Quality\n- Control Resources\n- Monitor Communications\n- Monitor Risks\n- Close Project or Phase",
#                         "md": "- Topic 3 Manage Project Risks with GenAI (K1, A3, A4)\n- Implement Risk Responses\n- Conduct Procurements\n- Monitor and Control Project Work\n- Perform Integrated Change Control\n- Monitor Stakeholder Engagement\n- Validate Scope\n- Control Scope\n- Control Schedule\n- Control Costs\n- Control Quality\n- Control Resources\n- Monitor Communications\n- Monitor Risks\n- Close Project or Phase",
#                         "bBox": {
#                             "x": 36,
#                             "y": 180.89,
#                             "w": 446.43,
#                             "h": 11
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "LO3 \u2013 Anticipate and devise risk mitigation measures with GenAI to ensure project success",
#                         "md": "# LO3 \u2013 Anticipate and devise risk mitigation measures with GenAI to ensure project success",
#                         "bBox": {
#                             "x": 36,
#                             "y": 180.89,
#                             "w": 478.95,
#                             "h": 365
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "K1: Project risk management",
#                         "md": "# K1: Project risk management",
# ...
#                                 "(inclusive tea breaks)",
#                                 "Written Assessment (SAQ)"
#                             ],
#                             [
#                                 "14 hrs",
#                                 "1 hr"
#                             ],
#                             [
#                                 "1 hr",
#                                 "Total"
#                             ],
#                             [
#                                 "16 hrs",
#                                 ""
#                             ]
#                         ],
#                         "md": "|Training Contact Time|Assessment Contact Time|\n|---|---|\n|(inclusive tea breaks)|Written Assessment (SAQ)|\n|14 hrs|1 hr|\n|1 hr|Total|\n|16 hrs| |",
#                         "isPerfectTable": true,
#                         "csv": "\"Training Contact Time\",\"Assessment Contact Time\"\n\"(inclusive tea breaks)\",\"Written Assessment (SAQ)\"\n\"14 hrs\",\"1 hr\"\n\"1 hr\",\"Total\"\n\"16 hrs\",\"\"",
#                         "bBox": {
#                             "x": 31,
#                             "y": 69.89,
#                             "w": 518.39,
#                             "h": 726
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "Classroom Training\n\n\u25cf 0900 hrs to 1830 hrs\n\nAssessment\n\n\u25cf 1600 hrs to 1800 hrs",
#                         "md": "Classroom Training\n\n\u25cf 0900 hrs to 1830 hrs\n\nAssessment\n\n\u25cf 1600 hrs to 1800 hrs",
#                         "bBox": {
#                             "x": 54,
#                             "y": 153.89,
#                             "w": 451.77,
#                             "h": 226
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Summary of Assessment Requirement:",
#                         "md": "# Summary of Assessment Requirement:",
#                         "bBox": {
#                             "x": 54,
#                             "y": 153.89,
#                             "w": 451.77,
#                             "h": 226
#                         }
#                     },
#                     {
#                         "type": "table",
#                         "rows": [
#                             [
#                                 "Learning Outcomes",
#                                 "Assessment Methods"
#                             ],
#                             [
#                                 "LO1: Develop project parameters with GenAI according to business requirements",
#                                 "WA-SAQ, CS"
#                             ],
#                             [
#                                 "LO2: Resolve project delivery challenges by optimizing resource and project budgets with GenAI.",
#                                 "WA-SAQ, CS"
#                             ],
#                             [
#                                 "LO3: Anticipate and devise risk mitigation measures with GenAI to ensure project success",
#                                 "WA-SAQ, CS"
#                             ]
#                         ],
#                         "md": "|Learning Outcomes|Assessment Methods|\n|---|---|\n|LO1: Develop project parameters with GenAI according to business requirements|WA-SAQ, CS|\n|LO2: Resolve project delivery challenges by optimizing resource and project budgets with GenAI.|WA-SAQ, CS|\n|LO3: Anticipate and devise risk mitigation measures with GenAI to ensure project success|WA-SAQ, CS|",
#                         "isPerfectTable": true,
#                         "csv": "\"Learning Outcomes\",\"Assessment Methods\"\n\"LO1: Develop project parameters with GenAI according to business requirements\",\"WA-SAQ, CS\"\n\"LO2: Resolve project delivery challenges by optimizing resource and project budgets with GenAI.\",\"WA-SAQ, CS\"\n\"LO3: Anticipate and devise risk mitigation measures with GenAI to ensure project success\",\"WA-SAQ, CS\"",
#                         "bBox": {
#                             "x": 65,
#                             "y": 375.89,
#                             "w": 429.91,
#                             "h": 93
#                         }
#                     },
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "Assessment duration and ratio",
#                         "md": "# Assessment duration and ratio",
#                         "bBox": {
#                             "x": 54,
#                             "y": 153.89,
#                             "w": 451.77,
#                             "h": 399
#                         }
#                     },
#                     {
#                         "type": "table",
#                         "rows": [
#                             [
#                                 "Method",
#                                 "Duration",
#                                 "Ratio (Assessor : Candidate)",
#                                 "Remarks"
#                             ],
#                             [
#                                 "Written Assessment, WA-SAQ",
#                                 "1 hr",
#                                 "Min: 1:3 Max: 1:20",
#                                 ""
#                             ],
#                             [
#                                 "Case Study (CS)",
#                                 "1 hr",
#                                 "Min: 1:3 Max: 1:20",
#                                 ""
#                             ],
#                             [
#                                 "Total",
#                                 "1 hr",
#                                 "",
#                                 "--"
#                             ]
#                         ],
#                         "md": "|Method|Duration|Ratio (Assessor : Candidate)|Remarks|\n|---|---|---|---|\n|Written Assessment, WA-SAQ|1 hr|Min: 1:3 Max: 1:20| |\n|Case Study (CS)|1 hr|Min: 1:3 Max: 1:20| |\n|Total|1 hr| |--|",
#                         "isPerfectTable": true,
#                         "csv": "\"Method\",\"Duration\",\"Ratio (Assessor : Candidate)\",\"Remarks\"\n\"Written Assessment, WA-SAQ\",\"1 hr\",\"Min: 1:3 Max: 1:20\",\"\"\n\"Case Study (CS)\",\"1 hr\",\"Min: 1:3 Max: 1:20\",\"\"\n\"Total\",\"1 hr\",\"\",\"--\"",
#                         "bBox": {
#                             "x": 31,
#                             "y": 69.89,
#                             "w": 518.39,
#                             "h": 726
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 13 of 14",
#                         "md": "Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 13 of 14",
#                         "bBox": {
#                             "x": 36,
#                             "y": 735.89,
#                             "w": 513.39,
#                             "h": 35
#                         }
#                     }
#                 ],
#                 "status": "OK",
#                 "links": [],
#                 "width": 595.303937007874,
#                 "height": 841.889763779528,
#                 "triggeredAutoMode": false,
#                 "structuredData": null,
#                 "noStructuredContent": false,
#                 "noTextContent": false
#             },
#             {
#                 "page": 14,
#                 "text": "6. Reference\n              1. Trainer Slides\n              2. Lesson Plan (LP)\n              3. Assessment Plan (AP)\n              4. Assessment Questions and Answers\n              5. Facilitator Guide (FG)\n              6. Learner Guide (LG)\n              7. Course Proposal (CP)\n  Copyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by\n  Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication,\n  distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for\n  purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\n  Page14 of 14",
#                 "md": "# 6. Reference\n\n1. Trainer Slides\n2. Lesson Plan (LP)\n3. Assessment Plan (AP)\n4. Assessment Questions and Answers\n5. Facilitator Guide (FG)\n6. Learner Guide (LG)\n7. Course Proposal (CP)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 14 of 14",
#                 "images": [],
#                 "charts": [],
#                 "items": [
#                     {
#                         "type": "heading",
#                         "lvl": 1,
#                         "value": "6. Reference",
#                         "md": "# 6. Reference",
#                         "bBox": {
#                             "x": 31,
#                             "y": 69.89,
#                             "w": 85.61,
#                             "h": 14
#                         }
#                     },
#                     {
#                         "type": "text",
#                         "value": "1. Trainer Slides\n2. Lesson Plan (LP)\n3. Assessment Plan (AP)\n4. Assessment Questions and Answers\n5. Facilitator Guide (FG)\n6. Learner Guide (LG)\n7. Course Proposal (CP)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 14 of 14",
#                         "md": "1. Trainer Slides\n2. Lesson Plan (LP)\n3. Assessment Plan (AP)\n4. Assessment Questions and Answers\n5. Facilitator Guide (FG)\n6. Learner Guide (LG)\n7. Course Proposal (CP)\n\nCopyright 2024, Tertiary Infotech Pte Ltd. All rights reserved. This document is provided for the explicit use and guidance of trainers approved by Tertiary Infotech Pte Ltd as information resource only. Any other use of this document or parts thereof, including reproduction, publication, distribution, transmission, re-transmission or public showing, or storage in a retrieval system in any form, electronic or otherwise, for purposes other than that expressly stated above without the express permission of Tertiary Infotech Pte Ltd is strictly prohibited.\n\nPage 14 of 14",
#                         "bBox": {
#                             "x": 36,
#                             "y": 100.89,
#                             "w": 513.39,
#                             "h": 670
#                         }
#                     }
#                 ],
#                 "status": "OK",
#                 "links": [],
#                 "width": 595.303937007874,
#                 "height": 841.889763779528,
#                 "triggeredAutoMode": false,
#                 "structuredData": null,
#                 "noStructuredContent": false,
#                 "noTextContent": false
#             }
#         ],
#         "job_metadata": {
#             "credits_used": 154.0,
#             "job_credits_usage": 14,
#             "job_pages": 14,
#             "job_auto_mode_triggered_pages": 0,
#             "job_is_cache_hit": false
#         },
#         "job_id": "ab8037a6-c891-42da-8ed5-b06ea54f6a3b",
#         "file_path": "input/FG_TGS-2024049183 - Project Management with Generative AI (GenAI)_v1.docx"
#     }
# ]
# Structured Data:
# course_title='Project Management with Generative AI (GenAI)' tsc_proficiency_level='5' learning_units=[LearningUnit(name='LU1: Project Initiation and Planning with GenAI', topics=[Topic(name='Project Initiation and Planning with GenAI', subtopics=['Initiating a Project - Overview', 'Develop Project Charter', 'Identify Stakeholders', 'Develop Project Management Plan', 'Plan Stakeholder Engagement', 'Plan Scope Management', 'Plan Schedule Management', 'Plan Cost Management', 'Plan Quality Management', 'Plan Resource Management', 'Plan Communications Management', 'Plan Risk Management', 'Plan Risk Responses', 'Plan Procurement Management'], tsc_knowledges=[KnowledgeStatement(id='K2', text='Building project master plans')], tsc_abilities=[AbilityStatement(id='A1', text='Develop project parameters according to business requirements')])], learning_outcome='Develop project parameters with GenAI according to business requirements'), LearningUnit(name='LU2: Project Execution and Delivery with GenAI', topics=[Topic(name='Project Execution and Delivery with GenAI', subtopics=['Direct and Manage Project Work', 'Manage Project Knowledge', 'Manage Stakeholder Engagement', 'Manage Quality', 'Acquire Resources', 'Manage Team'], tsc_knowledges=[KnowledgeStatement(id='K3', text='Optimisation of resource and project budgets')], tsc_abilities=[AbilityStatement(id='A2', text='Advise staff in resolving challenges during project delivery')])], learning_outcome='Resolve project delivery challenges by optimizing resource and project budgets with GenAI.'), LearningUnit(name='LU3: Manage Project Risks with GenAI', topics=[Topic(name='Manage Project Risks with GenAI', subtopics=['Implement Risk Responses', 'Conduct Procurements', 'Monitor and Control Project Work', 'Perform Integrated Change Control', 'Monitor Stakeholder Engagement', 'Validate Scope', 'Control Scope', 'Control Schedule', 'Control Costs', 'Control Quality', 'Control Resources', 'Monitor Communications', 'Monitor Risks', 'Close Project or Phase'], tsc_knowledges=[KnowledgeStatement(id='K1', text='Project risk management')], tsc_abilities=[AbilityStatement(id='A3', text='Anticipate potential risks to project delivery'), AbilityStatement(id='A4', text='Devise risk mitigation measures to ensure project success')])], learning_outcome='Anticipate and devise risk mitigation measures with GenAI to ensure project success')] assessments=[AssessmentMethod(code='WA-SAQ', duration='1 hr'), AssessmentMethod(code='CS', duration='1 hr')]

# %%
import pprint
pprint.pprint(dict(extracted_data))
# Out:
# {'assessments': [AssessmentMethod(code='WA-SAQ', duration='1 hr'),
#                  AssessmentMethod(code='CS', duration='1 hr')],
#  'course_title': 'Project Management with Generative AI (GenAI)',
#  'learning_units': [LearningUnit(name='LU1: Project Initiation and Planning with GenAI', topics=[Topic(name='Project Initiation and Planning with GenAI', subtopics=['Initiating a Project - Overview', 'Develop Project Charter', 'Identify Stakeholders', 'Develop Project Management Plan', 'Plan Stakeholder Engagement', 'Plan Scope Management', 'Plan Schedule Management', 'Plan Cost Management', 'Plan Quality Management', 'Plan Resource Management', 'Plan Communications Management', 'Plan Risk Management', 'Plan Risk Responses', 'Plan Procurement Management'], tsc_knowledges=[KnowledgeStatement(id='K2', text='Building project master plans')], tsc_abilities=[AbilityStatement(id='A1', text='Develop project parameters according to business requirements')])], learning_outcome='Develop project parameters with GenAI according to business requirements'),
#                     LearningUnit(name='LU2: Project Execution and Delivery with GenAI', topics=[Topic(name='Project Execution and Delivery with GenAI', subtopics=['Direct and Manage Project Work', 'Manage Project Knowledge', 'Manage Stakeholder Engagement', 'Manage Quality', 'Acquire Resources', 'Manage Team'], tsc_knowledges=[KnowledgeStatement(id='K3', text='Optimisation of resource and project budgets')], tsc_abilities=[AbilityStatement(id='A2', text='Advise staff in resolving challenges during project delivery')])], learning_outcome='Resolve project delivery challenges by optimizing resource and project budgets with GenAI.'),
#                     LearningUnit(name='LU3: Manage Project Risks with GenAI', topics=[Topic(name='Manage Project Risks with GenAI', subtopics=['Implement Risk Responses', 'Conduct Procurements', 'Monitor and Control Project Work', 'Perform Integrated Change Control', 'Monitor Stakeholder Engagement', 'Validate Scope', 'Control Scope', 'Control Schedule', 'Control Costs', 'Control Quality', 'Control Resources', 'Monitor Communications', 'Monitor Risks', 'Close Project or Phase'], tsc_knowledges=[KnowledgeStatement(id='K1', text='Project risk management')], tsc_abilities=[AbilityStatement(id='A3', text='Anticipate potential risks to project delivery'), AbilityStatement(id='A4', text='Devise risk mitigation measures to ensure project success')])], learning_outcome='Anticipate and devise risk mitigation measures with GenAI to ensure project success')],
#  'tsc_proficiency_level': '5'}

# %%
llm_config={
    "config_list": [
        {
            'model': "gpt-4o",
            'api_key': OPENAI_API_KEY,
        },
    ],
    "timeout": 300,
}

# %% [markdown]
# ## Short Answer Question (SAQ) Generation
#
# In this section, we generate Short Answer Questions (SAQs) based on the extracted data from the Facilitator Guide (FG) document. The process involves the following steps:
#
# 1. **Retrieve Content for Knowledge Statements**:
#     - The function `retrieve_content_for_knowledge_statement` retrieves content related to the knowledge statements from the provided data using the query engine.
#
# 2. **Generate Questions and Answers**:
#     - The `qa_generation_agent` generates scenario-based question-answer pairs for each knowledge statement.
#     - The questions are designed to align with Bloom's Taxonomy Level 3 (Applying) and provide concise, practical insights.
#
# 3. **Output Format**:
#     - The generated questions and answers are structured in a JSON format, ensuring they are ready for integration into assessment documents.
#
# 4. **Assessment Duration**:
#     - The duration for the SAQ assessment is extracted from the provided data.
#
# 5. **Execution**:
#     - The `user_proxy_agent` initiates the chat with the `qa_generation_agent` to generate the questions and answers based on the retrieved content and specified instructions.

# %%
from llama_index.llms.openai import OpenAI as llama_openai
from autogen import AssistantAgent, UserProxyAgent
from autogen.cache import Cache
import streamlit as st
import json
import re
import pprint

class FacilitatorGuideExtraction(BaseModel):
    course_title: str
    tsc_proficiency_level: str
    learning_units: List[LearningUnit]
    assessments: List[AssessmentMethod]

# %%
# Retrieve contents for the short answer questions
def retrieve_content_for_knowledge_statement(extracted_data: FacilitatorGuideExtraction, engine):
    """
    Retrieves content related to the knowledge statements from the provided data.

    Args:
        extracted_data (FacilitatorGuideExtraction): The extracted data instance containing course details.

    Returns:
        List[Dict]: A list of dictionaries containing retrieved content and associated abilities.
    """
    retrieved_content = []
    for learning_unit in extracted_data.learning_units:
        for topic in learning_unit.topics:
            for knowledge in topic.tsc_knowledges:
                knowledge_id = knowledge.id
                knowledge_statement = knowledge.text
                topic_name = topic.name
                # Query the index to retrieve topic content for this Knowledge Statement
                response = engine.query(
                    f"Retrieve the most relevant inline segments aligned to Knowledge Statement: {knowledge_statement}\n"
                    f"From the given Topic: {topic_name}"        
                )
                # pprint_response(response, show_source=True)

                # Add the structured data using Pydantic model
                try:
                    retrieved_content.append({
                        "knowledge_id": knowledge_id,
                        "knowledge_statement": knowledge_statement,
                        "retrieved_content": response.response
                    })
                except Exception as e:
                    print(f"Error adding structured data for {knowledge_id}: {e}")
    return retrieved_content

# %%
openai_api_key = llm_config["config_list"][0]["api_key"]

system_prompt = """\
You are a content retrieval assistant. Your role is to retrieve topic content that aligns strictly with the specified Knowledge Statement.

Your role:
1. Restrict your retrieval strictly to the specified topic provided in the query.
2. Retrieve content from the topic that directly aligns with the provided Knowledge Statement.
3. If no specific content directly aligns with the Knowledge Statement, provide a general summary of the specified topic instead.
4. Include any example/usecase code or equations relevant to the topic or subtopics.
5. Prioritize retrieving content that are theoretical.
6. Identify and extract the exact inline segments from the provided documents that directly correspond to the content used to generate the given answer. The extracted segments must be verbatim snippets from the documents, ensuring a word-for-word match with the text in the provided documents.

Ensure that:
- (Important) Each retrieved segment is an exact match to a part of the document and is fully contained within the document text.
- The relevance of each segment to the Knowledge Statement is clear and directly supports the summary provided.
- (Important) If you didn't used the specific document or topic, do not mention it.
- If no relevant information is found for the Knowledge Statement, clearly state this and provide a general topic summary instead.

Restrictions:
- Do not include content from other topics or slides outside the specified topic.
- Each retrieved segment must explicitly belong to the given topic.
- Avoid including assumptions or content outside the scope of the Knowledge Statement.

You must always provide:
1. The retrieved content aligned with the Knowledge Statement.
2. A list of verbatim extracted segments that directly support the retrieved content, each labeled with the topic and document it belongs to.
"""
ks_generation_llm = llama_openai(model="gpt-4o-mini", api_key=openai_api_key, system_prompt=system_prompt)
ks_generation_query_engine = index.as_query_engine(
    similarity_top_k=10,
    llm=ks_generation_llm,
    response_mode="tree_summarize"
    # response_mode="compact",
    # node_postprocessors=[cohere_rerank],
)
retrieved_content = retrieve_content_for_knowledge_statement(extracted_data, ks_generation_query_engine)

# %%
pprint.pprint(retrieved_content)
# Out:
# [{'knowledge_id': 'K1',
#   'knowledge_statement': 'Process characterization',
#   'retrieved_content': 'No specific content directly aligns with the Knowledge '
#                        'Statement "Process characterization" from the provided '
#                        'documents. \n'
#                        '\n'
#                        '**General Summary of the Topic: Fundamentals of Design '
#                        'of Experiment (K1, A1):**\n'
#                        'The Fundamentals of Design of Experiment (DOE) involve '
#                        'systematic methods for planning, conducting, '
#                        'analyzing, and interpreting controlled tests to '
#                        'evaluate the factors that may influence a particular '
#                        'outcome or process. Key concepts include:\n'
#                        '\n'
#                        '1. **Process Characterization**: Understanding the '
#                        'relationships between input variables (factors) and '
#                        'output responses (results) to optimize processes.\n'
#                        '2. **Experimental Design**: Selecting a set of '
#                        'experiments that will provide the most information '
#                        'about the system being studied while minimizing costs '
#                        'and time.\n'
#                        '3. **Statistical Analysis**: Using statistical methods '
#                        'to analyze the data collected from experiments to draw '
#                        'valid conclusions.\n'
#                        '\n'
#                        '**Example/Use Case Code:**\n'
#                        'In a typical DOE scenario, one might use statistical '
#                        'software or programming languages like Python or R to '
#                        "analyze the results. For example, using Python's "
#                        '`statsmodels` library:\n'
#                        '\n'
#                        '```python\n'
#                        'import statsmodels.api as sm\n'
#                        'from statsmodels.formula.api import ols\n'
#                        '\n'
#                        '# Example data\n'
#                        'data = {\n'
#                        "    'response': [23, 45, 67, 34, 56, 78],\n"
#                        "    'factor1': ['A', 'A', 'B', 'B', 'C', 'C'],\n"
#                        "    'factor2': [1, 2, 1, 2, 1, 2]\n"
#                        '}\n'
#                        '\n'
#                        '# Create a DataFrame\n'
#                        'import pandas as pd\n'
#                        'df = pd.DataFrame(data)\n'
#                        '\n'
#                        '# Fit the model\n'
#                        "model = ols('response ~ C(factor1) + C(factor2)', "
#                        'data=df).fit()\n'
#                        'anova_table = sm.stats.anova_lm(model, typ=2)\n'
#                        '\n'
#                        'print(anova_table)\n'
#                        '```\n'
#                        '\n'
#                        'This code snippet demonstrates how to perform an ANOVA '
#                        'test to analyze the effects of two factors on a '
#                        'response variable.\n'
#                        '\n'
#                        '**Verbatim Extracted Segments:**\n'
#                        '- No relevant segments were found that directly '
#                        'correspond to the Knowledge Statement "Process '
#                        'characterization." \n'
#                        '\n'
#                        'If you need further assistance or specific '
#                        'information, please let me know!'},
#  {'knowledge_id': 'K2',
#   'knowledge_statement': 'Types of performance metrics',
#   'retrieved_content': 'No relevant information was found regarding "Types of '
#                        'performance metrics" in the context of "Factorial DoE '
#                        '(K2, A2)." \n'
#                        '\n'
#                        'Here is a general summary of the topic:\n'
#                        '\n'
#                        '**Factorial Design of Experiments (DoE)** is a '
#                        'systematic method used to evaluate the effects of '
#                        'multiple factors on a response variable. It allows '
#                        'researchers to understand how different variables '
#                        'interact with each other and influence outcomes. The '
#                        'performance metrics in this context typically '
#                        'include:\n'
#                        '\n'
#                        '1. **Main Effects**: The individual impact of each '
#                        'factor on the response variable.\n'
#                        '2. **Interaction Effects**: How the combination of '
#                        'factors affects the response variable differently than '
#                        'the individual factors alone.\n'
#                        '3. **Variance Analysis**: Assessing the variability in '
#                        'the response data to determine the significance of '
#                        'factors.\n'
#                        '4. **Response Surface Methodology**: A collection of '
#                        'mathematical and statistical techniques useful for '
#                        'modeling and analyzing problems in which a response of '
#                        'interest is influenced by several variables.\n'
#                        '\n'
#                        'If you need more specific information or details on a '
#                        'different topic, please let me know!'},
#  {'knowledge_id': 'K3',
#   'knowledge_statement': 'Problem solving techniques',
#   'retrieved_content': 'No specific content directly aligns with the Knowledge '
#                        'Statement "Problem solving techniques" from the '
#                        'provided documents. Therefore, a general summary of '
#                        'the topic "Screening, Modeling and Optimizing DoE" is '
#                        'provided below.\n'
#                        '\n'
#                        '**Summary of Screening, Modeling and Optimizing '
#                        'DoE:**\n'
#                        'Design of Experiments (DoE) is a statistical approach '
#                        'used to plan, conduct, and analyze experiments '
#                        'efficiently. It helps in understanding the '
#                        'relationship between factors affecting a process and '
#                        'the output of that process. The key components of DoE '
#                        'include:\n'
#                        '\n'
#                        '1. **Screening:** This phase involves identifying the '
#                        'most significant factors that influence the response '
#                        'variable. Techniques such as factorial designs or '
#                        'fractional factorial designs are commonly used to '
#                        'evaluate multiple factors simultaneously.\n'
#                        '\n'
#                        '2. **Modeling:** After screening, the next step is to '
#                        'develop a mathematical model that describes the '
#                        'relationship between the factors and the response. '
#                        'This can involve regression analysis or other '
#                        'statistical modeling techniques to predict outcomes '
#                        'based on different input levels.\n'
#                        '\n'
#                        '3. **Optimizing:** The final phase focuses on finding '
#                        'the optimal levels of the factors to achieve the '
#                        'desired response. This can involve techniques such as '
#                        'response surface methodology (RSM) or optimization '
#                        'algorithms to explore the factor space and identify '
#                        'the best conditions.\n'
#                        '\n'
#                        'These techniques are essential for improving '
#                        'processes, enhancing product quality, and reducing '
#                        'costs in various industries.\n'
#                        '\n'
#                        '**Verbatim Extracted Segments:**\n'
#                        '- No specific segments were found that directly '
#                        'correspond to the Knowledge Statement "Problem solving '
#                        'techniques" in the provided documents.'}]

# %%
user_proxy_agent = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",   
    max_consecutive_auto_reply=5,
    is_termination_msg=lambda msg: msg.get("content", "") and "TERMINATE" in msg["content"],
    code_execution_config={"work_dir": "output", "use_docker": False, "response_format": {"type": "json_object"}}
)

# Autogen setup
qa_generation_agent = AssistantAgent(
    name="question_answer_generator",
    system_message=f"""
    You are an expert educator in '{extracted_data.course_title}'. 
    You will create knowledge-based scenario question-answer pairs based on the retrieved content.

    ### Instructions:
    1. Generate **exactly one** question-and-answer pair per knowledge statement.
    2. **Scenario Requirements**:
       - Provide a **2–3 sentence** realistic scenario that offers context.
       - Describe an industry, organization, or setting related to the knowledge statement.
       - Include a brief goal or problem the scenario is trying to solve.
       - Write it in an **"analyze and recommend"** style, aligned with Bloom's Taxonomy Level 3 (Applying).
       - Example: 
         "An eCommerce company is considering AI applications but is unsure of the specific areas where AI could make the most impact. Analyze and recommend areas within the eCommerce industry where AI is most applicable."
    3. **Question Requirements**:
       - Phrase the question so it aligns with the scenario and Bloom's Taxonomy Level 3 (Applying).
       - Example:
         "Which AI applications can be implemented for maximum impact, and how should they be prioritized?"
    4. **Answer Requirements**:
       - Short Answer Question (SAQ) style.
       - Provide 3–4 concise bullet points **only** (no extra commentary).
       - Each bullet should be a key knowledge point or practical insight.
    5. **If no relevant content** is found for a given knowledge statement:
       - "scenario": "No relevant scenario found."
       - "question_statement": "No relevant content found for this knowledge statement."
       - "answer": ["No relevant content found."]
    6. Structure the final output in **valid JSON** with the format:

    ```json
    {{
        "course_title": "<course_title_here>",
        "duration": "<assessment_duration>",
        "questions": [
            {{
                "scenario": "<scenario>",
                "question_statement": "<question>",
                "knowledge_id": "<knowledge_id>",
                "answer": [
                    "<bullet_point_1>",
                    "<bullet_point_2>",
                    "<bullet_point_3>"
                ]
            }},
            ...
        ]
    }}
    ```
    
    7. Return the JSON between triple backticks followed by 'TERMINATE'.
    """,
    llm_config=llm_config,
)

assessment_duration = ""
for assessment in extracted_data.assessments:
    if "SAQ" in assessment.code:
        assessment_duration = assessment.duration
saq_context = {}
with Cache.disk() as cache:
    chat_result = user_proxy_agent.initiate_chat(
        qa_generation_agent,
        message=f"""
        Please generate the questions and answers using the following course title: '{extracted_data.course_title}', 
        assessment duration: '{assessment_duration}', and topic contents: {retrieved_content}.
        Ensure suggestive answers are provided as bullet points, concise and practical, covering key aspects of the knowledge statement.
        Phrase questions in alignment with Bloom's Taxonomy Level: {extracted_data.tsc_proficiency_level}.
        Bloom's Taxonomy Levels:
            Level 1: Remembering
            Level 2: Understanding
            Level 3: Applying
            Level 4: Analyzing
            Level 5: Evaluating
            Level 6: Creating
        Return the output in JSON string format with specific detailed answers as bullet points.
        RETURN 'TERMINATE' once the generation is complete.
        """,
        summary_method="reflection_with_llm",
        cache=cache,
)
try:
    last_message_content = chat_result.chat_history[-1].get("content", "")
    if not last_message_content:
        print("No content found in the agent's last message.")
    last_message_content = last_message_content.strip()
    json_pattern = re.compile(r'```json\s*(\{.*?\})\s*```', re.DOTALL)
    json_match = json_pattern.search(last_message_content)
    if json_match:
        json_str = json_match.group(1)
        context = json.loads(json_str)
        saq_context = context
        print(f"CONTEXT JSON MAPPING: \n\n{context}")
    pprint.pprint(f"SAQ cost: {chat_result.cost}")
except json.JSONDecodeError as e:
    print(f"Error parsing context JSON: {e}")
# Out:
# [autogen.oai.client: 12-24 13:12:10] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# user_proxy (to question_answer_generator):
#
#
#         Please generate the questions and answers using the following course title: 'Project Management with Generative AI (GenAI)',
#         assessment duration: '1 hr', and topic contents: [{'knowledge_id': 'K2', 'knowledge_statement': 'Building project master plans', 'retrieved_content': 'To build project master plans, the following key components and processes are essential:\n\n1. **Develop Project Management Plan**: This involves creating a comprehensive plan that outlines how the project will be executed, monitored, and controlled. It serves as a roadmap for the project team.\n\n2. **Plan Scope Management**: This includes defining and controlling what is included and excluded in the project. It ensures that all necessary work is included to complete the project successfully.\n\n3. **Plan Schedule Management**: This process involves determining the policies, procedures, and documentation for planning, developing, managing, executing, and controlling the project schedule.\n\n4. **Plan Cost Management**: This entails establishing the policies, procedures, and documentation for planning, managing, and controlling project costs.\n\n5. **Plan Quality Management**: This focuses on identifying the quality requirements and/or standards for the project and its deliverables, and documenting how the project will demonstrate compliance.\n\n6. **Plan Resource Management**: This involves identifying and documenting project roles, responsibilities, required skills, and reporting relationships, as well as creating a staffing management plan.\n\n7. **Plan Communications Management**: This process defines the communication requirements for the project and how information will be distributed.\n\n8. **Plan Risk Management**: This includes defining how to conduct risk management activities for a project, which is crucial for identifying potential risks and planning responses.\n\n9. **Plan Procurement Management**: This involves determining what to procure, how to procure it, and when to procure it, ensuring that all necessary resources are available for project execution.\n\n10. **Plan Stakeholder Engagement**: This process involves developing strategies to effectively engage stakeholders throughout the project lifecycle.\n\n### Extracted Segments:\n- "Develop Project Management Plan"\n- "Plan Scope Management"\n- "Plan Schedule Management"\n- "Plan Cost Management"\n- "Plan Quality Management"\n- "Plan Resource Management"\n- "Plan Communications Management"\n- "Plan Risk Management"\n- "Plan Procurement Management"\n- "Plan Stakeholder Engagement"\n\nThese segments highlight the critical aspects of building project master plans within the context of project initiation and planning with Generative AI (GenAI).'}, {'knowledge_id': 'K3', 'knowledge_statement': 'Optimisation of resource and project budgets', 'retrieved_content': 'The optimization of resource and project budgets is a critical aspect of project management, particularly in the context of project execution and delivery with Generative AI (GenAI). This involves effectively managing resources to ensure that the project is completed within the allocated budget while maximizing efficiency and minimizing waste.\n\nKey points regarding the optimization of resources and project budgets include:\n\n1. **Resource Management Plan**: This plan outlines how resources will be identified, acquired, and managed throughout the project lifecycle. It includes details on roles, responsibilities, and the allocation of resources to ensure that the project remains within budget.\n\n2. **Cost Management**: This involves estimating costs, determining budgets, and controlling costs to ensure that the project does not exceed its financial limits. Techniques such as Earned Value Management (EVM) can be used to assess project performance against the budget.\n\n3. **Resource Optimization Techniques**: Techniques such as resource leveling and resource smoothing are employed to ensure that resources are allocated efficiently and that any over-allocation is addressed without impacting the project schedule.\n\n4. **Continuous Monitoring**: Regula ...
#         Ensure suggestive answers are provided as bullet points, concise and practical, covering key aspects of the knowledge statement.
#         Phrase questions in alignment with Bloom's Taxonomy Level: 5.
#         Bloom's Taxonomy Levels:
#             Level 1: Remembering
#             Level 2: Understanding
#             Level 3: Applying
#             Level 4: Analyzing
#             Level 5: Evaluating
#             Level 6: Creating
#         Return the output in JSON string format with specific detailed answers as bullet points.
#         RETURN 'TERMINATE' once the generation is complete.
#
#
# --------------------------------------------------------------------------------
# question_answer_generator (to user_proxy):
#
# ```json
# {
#     "course_title": "Project Management with Generative AI (GenAI)",
#     "duration": "1 hr",
#     "questions": [
#         {
#             "scenario": "A software development company is tasked with delivering a new enterprise application on time and within budget. They need to create a comprehensive project master plan to guide their efforts effectively. Analyze and recommend the essential components and processes for building an effective project master plan using Generative AI (GenAI).",
#             "question_statement": "What are the key components and processes involved in building a project master plan, and how can GenAI facilitate this process?",
#             "knowledge_id": "K2",
#             "answer": [
#                 "Develop a Project Management Plan outlining execution, monitoring, and controlling processes.",
#                 "Plan cost, quality, and resource management to maintain budget and performance standards.",
#                 "Implement stakeholder engagement strategies to ensure effective communication and responsiveness.",
#                 "Utilize GenAI tools to automate and optimize planning processes, enhancing efficiency."
#             ]
#         },
#         {
#             "scenario": "A construction firm aims to optimize its ongoing project resources and budget to enhance profitability and sustainability. They are exploring advanced tools, including Generative AI, as potential solutions. Evaluate the techniques and strategies that can be employed for resource and budget optimization with the assistance of GenAI.",
#             "question_statement": "What strategies can be used to optimize resource management and project budgets, and how can GenAI aid in this process?",
#             "knowledge_id": "K3",
#             "answer": [
#                 "Implement a Resource Management Plan to allocate roles and responsibilities efficiently.",
#                 "Utilize Cost Management techniques, such as Earned Value Management, to control financial flow.",
#                 "Apply Resource Optimization Techniques like resource leveling to manage allocations.",
#                 "Leverage GenAI for data-driven insights on resource allocation and budget utilization."
#             ]
#         },
#         {
#             "scenario": "A manufacturing company faced with volatile market conditions is implementing a new production line. They need a robust risk management strategy to minimize disruptions and capitalize on opportunities. Examine the role of GenAI in supporting project risk management and how it could improve risk response planning.",
#             "question_statement": "How can GenAI enhance project risk management processes, particularly in identifying and responding to potential risks?",
#             "knowledge_id": "K1",
#             "answer": [
#                 "Develop a Risk Management Plan incorporating GenAI to foresee potential issues.",
#                 "Use GenAI to aid in identifying risks and maintaining an up-to-date Risk Register.",
#                 "Implement a Plan Risk Responses strategy where GenAI helps in scenario analysis and response planning.",
#                 "Continuously monitor risks using GenAI to adjust strategies in real-time."
#             ]
#         }
#     ]
# }
# ```
# TERMINATE
#
# --------------------------------------------------------------------------------
# CONTEXT JSON MAPPING:
#
# {'course_title': 'Project Management with Generative AI (GenAI)', 'duration': '1 hr', 'questions': [{'scenario': 'A software development company is tasked with delivering a new enterprise application on time and within budget. They need to create a comprehensive project master plan to guide their efforts effectively. Analyze and recommend the essential components and processes for building an effective project master plan using Generative AI (GenAI).', 'question_statement': 'What are the key components and processes involved in building a project master plan, and how can GenAI facilitate this process?', 'knowledge_id': 'K2', 'answer': ['Develop a Project Management Plan outlining execution, monitoring, and controlling processes.', 'Plan cost, quality, and resource management to maintain budget and performance standards.', 'Implement stakeholder engagement strategies to ensure effective communication and responsiveness.', 'Utilize GenAI tools to automate and optimize planning processes, enhancing efficiency.']}, {'scenario': 'A construction firm aims to optimize its ongoing project resources and budget to enhance profitability and sustainability. They are exploring advanced tools, including Generative AI, as potential solutions. Evaluate the techniques and strategies that can be employed for resource and budget optimization with the assistance of GenAI.', 'question_statement': 'What strategies can be used to optimize resource management and project budgets, and how can GenAI aid in this process?', 'knowledge_id': 'K3', 'answer': ['Implement a Resource Management Plan to allocate roles and responsibilities efficiently.', 'Utilize Cost Management techniques, such as Earned Value Management, to control financial flow.', 'Apply Resource Optimization Techniques like resource leveling to manage allocations.', 'Leverage GenAI for data-driven insights on resource allocation and budget utilization.']}, {'scenario': 'A manufacturing company faced with volatile market conditions is implementing a new production line. They need a robust risk management strategy to minimize disruptions and capitalize on opportunities. Examine the role of GenAI in supporting project risk management and how it could improve risk response planning.', 'question_statement': 'How can GenAI enhance project risk management processes, particularly in identifying and responding to potential risks?', 'knowledge_id': 'K1', 'answer': ['Develop a Risk Management Plan incorporating GenAI to foresee potential issues.', 'Use GenAI to aid in identifying risks and maintaining an up-to-date Risk Register.', 'Implement a Plan Risk Responses strategy where GenAI helps in scenario analysis and response planning.', 'Continuously monitor risks using GenAI to adjust strategies in real-time.']}]}
# ("SAQ cost: {'usage_including_cached_inference': {'total_cost': "
#  "0.018692499999999997, 'gpt-4o-2024-08-06': {'cost': 0.018692499999999997, "
#  "'prompt_tokens': 4925, 'completion_tokens': 638, 'total_tokens': 5563}}, "
#  "'usage_excluding_cached_inference': {'total_cost': 0.018692499999999997, "
#  "'gpt-4o-2024-08-06': {'cost': 0.018692499999999997, 'prompt_tokens': 4925, "
#  "'completion_tokens': 638, 'total_tokens': 5563}}}")

# %%
import os
import tempfile
from docxtpl import DocxTemplate

def _ensure_list(answer):
    """
    Returns a list regardless of whether 'answer' is originally a list, string, or None.
    """
    if isinstance(answer, list):
        return answer
    elif isinstance(answer, str):
        # Wrap the string in a list so Jinja loops or docxtpl loops won't break
        return [answer]
    return []

def generate_documents(context: dict, assessment_type: str, output_dir: str) -> dict:
    """
    Generate the question paper and answer paper for the given context and type.

    Parameters:
    - context (dict): The data for the assessment (course title, type, questions, etc.).
    - assessment_type (str): The assessment type (e.g., 'Ability-based', 'Knowledge-based').
    - output_dir (str): Directory where the generated documents will be saved.

    Returns:
    - dict: Paths to the generated documents (question and answer papers).
    """

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Load template paths
    TEMPLATES = {
        "QUESTION": f"../Templates/(Template) {assessment_type} - Course Title - v1.docx",
        "ANSWER": f"../Templates/(Template) Answer to {assessment_type} - Course Title - v1.docx"
    }


    qn_template = TEMPLATES["QUESTION"]
    ans_template = TEMPLATES["ANSWER"]

    question_doc = DocxTemplate(qn_template)
    answer_doc = DocxTemplate(ans_template)
    
    # Prepare context for the answer paper:
    # Convert each question's 'answer' to a list if it's a string or None
    answer_context = {
        **context,
        "questions": [
            {
                **question,
                "answer": _ensure_list(question.get("answer"))
            }
            for question in context.get("questions", [])
        ]
    }

    # Prepare context for the question paper by creating a copy of the context without answers
    question_context = {
        **context,
        "questions": [
            {
                **question,
                "answer": None  # Remove answers for the question doc
            }
            for question in context.get("questions", [])
        ]
    }

    # Render both templates
    # IMPORTANT FIX: Use answer_context instead of context for the answer doc
    answer_doc.render(answer_context)
    question_doc.render(question_context)

    # Create temporary files for the question and answer documents
    question_tempfile = tempfile.NamedTemporaryFile(
        delete=False, suffix=f"_{assessment_type} - {context.get('course_title')} - v1.docx"
    )
    answer_tempfile = tempfile.NamedTemporaryFile(
        delete=False, suffix=f"Answer to {assessment_type} - {context.get('course_title')} - v1.docx"
    )

    # Save the rendered documents to the temporary files
    question_doc.save(question_tempfile.name)
    answer_doc.save(answer_tempfile.name)

    return {
        "ASSESSMENT_TYPE": assessment_type,
        "QUESTION": question_tempfile.name,
        "ANSWER": answer_tempfile.name
    }

# %%
files = generate_documents(
    context=saq_context, 
    assessment_type="WA (SAQ)",
    output_dir="output"
)

print(f"Generated documents: {files}")
# Out:
# Generated documents: {'ASSESSMENT_TYPE': 'WA (SAQ)', 'QUESTION': 'C:\\Users\\dljh1\\AppData\\Local\\Temp\\tmptbzljew8_WA (SAQ) - Project Management with Generative AI (GenAI) - v1.docx', 'ANSWER': 'C:\\Users\\dljh1\\AppData\\Local\\Temp\\tmpifkrivg0Answer to WA (SAQ) - Project Management with Generative AI (GenAI) - v1.docx'}

# %% [markdown]
# ## Practical Performance (PP) Scenario Generation
#
# In this section, we generate a practical performance (PP) scenario based on the extracted data from the Facilitator Guide (FG) document. The process involves the following steps:
#
# 1. **Generate a Realistic Scenario**:
#     - The function `generate_pp_scenario` creates a concise, realistic scenario for the practical performance assessment.
#     - The scenario aligns with the course title, learning outcomes, and abilities.
#
# 2. **Retrieve Content for Learning Outcomes**:
#     - The `retrieve_content_for_learning_outcomes` function retrieves content related to the learning outcomes and abilities from the provided data using the query engine.
#
# 3. **Generate Questions and Answers**:
#     - The `qa_generation_agent` generates practical performance question-answer pairs based on the scenario and retrieved content.
#     - The questions describe hands-on tasks or practical activities related to the scenario.
#     - The answers provide the exact solutions or outputs for the tasks.
#
# 4. **Output Format**:
#     - The generated questions and answers are structured in a JSON format, ensuring they are ready for integration into assessment documents.
#
# 5. **Assessment Duration**:
#     - The duration for the practical performance assessment is extracted from the provided data.
#
# 6. **Execution**:
#     - The `user_proxy_agent` initiates the chat with the `qa_generation_agent` to generate the questions and answers based on the scenario and retrieved content.

# %%
class FacilitatorGuideExtraction(BaseModel):
    course_title: str
    tsc_proficiency_level: str
    learning_units: List[LearningUnit]
    assessments: List[AssessmentMethod]

def generate_pp_scenario(data: FacilitatorGuideExtraction, engine) -> str:
    """
    Generates a concise, realistic scenario for the practical performance.
    Args:
        course_title (str): The title of the course.
        learning_outcomes (List[str]): A list of learning outcomes.

    Returns:
        str: A concise scenario for the case study.
    """
    
    # Retrieve the course title and bloom taxonomy level
    course_title = data.course_title
    bloom_taxonomy_level = data.tsc_proficiency_level

    # Extract the learning outcomes as a list of strings
    learning_outcomes = [lu.learning_outcome for lu in data.learning_units]
    abilities = [ability.text for lu in data.learning_units for topic in lu.topics for ability in topic.tsc_abilities]
    
    outcomes_text = "\n".join([f"- {lo}" for lo in learning_outcomes])
    abilities_text = "\n".join([f"- {ability}" for ability in abilities])

    prompt = (
        f"You are tasked with designing a realistic practical performance assessment scenario for the course '{course_title}'.\n\n"
        f"The scenario should align with the following:\n\n"
        f"Learning Outcomes:\n{outcomes_text}\n\n"
        f"Abilities:\n{abilities_text}\n\n"
        f"Bloom's Taxonomy Level:\n{bloom_taxonomy_level}\n\n"
        "The scenario should describe a company or organization facing practical challenges and provide context for the learners to apply their skills.\n"
        "Ensure the scenario is concise (1 paragraph), realistic, and action-oriented, focusing on the summary of tasks learners must perform without requiring extensive deliverables."
    )
    response = engine.query(prompt)
    return response.response.strip()

def retrieve_content_for_learning_outcomes(extracted_data, engine):
    """
    Retrieves content related to the learning outcomes and abilities from the provided data.

    Args:
        extracted_data (FacilitatorGuideExtraction): The extracted data instance containing course details.

    Returns:
        List[Dict]: A list of dictionaries containing retrieved content and associated abilities.
    """
    retrieved_content = []

    for learning_unit in extracted_data.learning_units:
        learning_outcome = learning_unit.learning_outcome
        associated_abilities = []
        ability_ids = []
        for topic in learning_unit.topics:
            associated_abilities.extend(topic.tsc_abilities)
            ability_ids.extend([ability.id for ability in topic.tsc_abilities])

        # Define the content retrieval prompt
        retrieval_prompt = (
            f"Retrieve the most relevant inline segments aligned to Learning Outcome: {learning_outcome}\n"
            f"Associated Abilities:\n"
            + "\n".join([f"- [{ability.id}] {ability.text}" for ability in associated_abilities])
            + f"\nFrom the given Topics: {', '.join([topic.name for topic in learning_unit.topics])}"
        )

        response = engine.query(retrieval_prompt)
        retrieved_content.append({
            "learning_outcome": learning_outcome,
            "abilities": ability_ids,
            "retrieved_content": response.response
        })
    
    return retrieved_content

# %%
import os
import re
import json
import pprint
from autogen import AssistantAgent, UserProxyAgent
from autogen.cache import Cache
from llama_index.llms.openai import OpenAI as llama_openai


openai_api_key = OPENAI_API_KEY
system_prompt = """\
You are an instructional design assistant tasked with generating concise, realistic, and practical scenario-based question-answer pairs for educational purposes.

Your role:
1. **Generate a real-world scenario** for the given Course Title and Learning Outcome (LO). The scenario must:
- Be concise (1-2 paragraphs) while clearly describing the organizational challenges or context.
- Align directly with the Learning Outcome and be applicable to the associated abilities.
- Highlight specific organizational data, challenges, and objectives to ensure relevance and practicality.

2. Use only the information relevant to the specified Learning Unit, Learning Outcome, and its abilities. Do not include information from unrelated topics.

3. Ensure that:
- Each scenario and question-answer pair is realistic, aligned to Bloom's Taxonomy level for the LO, and practically applicable.
- If no relevant content exists, create a general scenario that remains educationally valuable and tied to the broader course theme.
    
**Output Format:**
- Tase study scenario have to be at least 500 words long.
- You will output your response in the following format. For example:
TechFusion, a leading software solutions provider, has been approached by a global bank to develop a new mobile banking application. The bank wants to offer its customers a seamless, secure, and intuitive banking experience on their smartphones. Given the competitive landscape, the bank emphasizes the need for rapid delivery without compromising on quality. TechFusion has recently adopted Agile methodologies with Scrum and DevOps practices and sees this project as an opportunity to showcase its capabilities in these areas.

**Restrictions:**
- Do not include content from other topics or unrelated slides.
- Do not invent abilities or knowledge outside the scope of the LO and its associated abilities.
"""

scenario_llm = llama_openai(model="gpt-4o-mini", api_key=openai_api_key, system_prompt=system_prompt)

scenario_query_engine = index.as_query_engine(
    similarity_top_k=10,
    llm=scenario_llm,
    response_mode="compact",
)
# Generate the shared scenario
scenario = generate_pp_scenario(extracted_data, scenario_query_engine)

system_prompt = """\
You are a content retrieval assistant. Your role is to retrieve topic content that aligns strictly with the specified Learning Outcome (LO) and its associated abilities.

Your role:
1. Restrict your retrieval strictly to the specified topic provided in the query.
2. Retrieve content from the topic that directly aligns with the provided Learning Outcome (LO) and its abilities.
3. If no specific content directly aligns with the Learning Outcome or abilities, provide a general summary of the topic instead.
4. Include any example/usecase code or equations relevant to the topic or subtopics.
5. Prioritize retrieving content that are practical.
6. Identify and extract the exact inline segments from the provided documents that directly correspond to the content used to generate the summary. The extracted segments must be verbatim snippets from the documents, ensuring a word-for-word match with the text in the provided documents.

Ensure that:
- (Important) Each retrieved segment is an exact match to a part of the document and is fully contained within the document text.
- The relevance of each segment to the Learning Outcome or abilities is clear and directly supports the summary provided.
- (Important) If you didn't use the specific document or topic, do not mention it.
- If no relevant information is found for the Learning Outcome, clearly state this and provide a general topic summary instead.

Restrictions:
- Do not include content from other topics or slides outside the specified topic.
- Each retrieved segment must explicitly belong to the given topic.
- Avoid including assumptions or content outside the scope of the Learning Outcome and abilities.

You must always provide:
1. The retrieved content aligned with the Learning Outcome and abilities.
2. A list of verbatim extracted segments that directly support the retrieved content, each labeled with the topic and document it belongs to.
"""

lo_retriever_llm = llama_openai(model="gpt-4o-mini", api_key=openai_api_key, system_prompt=system_prompt)
qa_generation_query_engine = index.as_query_engine(
    similarity_top_k=10,
    llm=lo_retriever_llm,
    response_mode="tree_summarize",
)
retrieved_content = retrieve_content_for_learning_outcomes(extracted_data, qa_generation_query_engine)
pprint.pprint(retrieved_content)
# Out:
# [{'abilities': ['A1'],
#   'learning_outcome': 'Analyze process interactions to characterize key '
#                       'factors influencing performance in Design of '
#                       'Experiments (DoE).',
#   'retrieved_content': 'No specific content related to the Learning Outcome of '
#                        'analyzing process interactions to characterize key '
#                        'factors influencing performance in Design of '
#                        'Experiments (DoE) was found in the provided '
#                        'documents. \n'
#                        '\n'
#                        'Here is a general summary of the topic:\n'
#                        '\n'
#                        '**Design of Experiments (DoE)** is a statistical '
#                        'approach used to plan, conduct, and analyze controlled '
#                        'tests to evaluate the factors that may influence a '
#                        'particular outcome. The fundamental goal of DoE is to '
#                        'identify the relationships between factors affecting a '
#                        'process and the output of that process. By '
#                        'systematically varying the input factors and observing '
#                        'the resulting changes in output, researchers can '
#                        'determine which factors are significant and how they '
#                        'interact with each other.\n'
#                        '\n'
#                        'Key aspects of DoE include:\n'
#                        '- **Factorial Designs**: These designs allow for the '
#                        'evaluation of multiple factors simultaneously, '
#                        'providing insights into interactions between factors.\n'
#                        '- **Randomization**: This helps to eliminate bias and '
#                        'ensures that the results are generalizable.\n'
#                        '- **Replication**: Repeating experiments to ensure '
#                        'reliability and accuracy of results.\n'
#                        '- **Analysis of Variance (ANOVA)**: A statistical '
#                        'method used to determine if there are significant '
#                        'differences between the means of different groups.\n'
#                        '\n'
#                        'In practice, DoE can be applied in various fields such '
#                        'as manufacturing, agriculture, and pharmaceuticals to '
#                        'optimize processes and improve product quality.\n'
#                        '\n'
#                        'If you need further information or specific examples '
#                        'related to DoE, please let me know!'},
#  {'abilities': ['A2'],
#   'learning_outcome': 'Select suitable factorial DoE projects by evaluating '
#                       'relevant performance metrics.',
#   'retrieved_content': 'No specific content directly aligns with the Learning '
#                        'Outcome of selecting suitable factorial DoE projects '
#                        'by evaluating relevant performance metrics, nor does '
#                        'it correspond to the associated ability of selecting '
#                        'appropriate new or continuous process integration '
#                        'improvement projects. \n'
#                        '\n'
#                        'Here is a general summary of the topic of Factorial '
#                        'Design of Experiments (DoE):\n'
#                        '\n'
#                        '**Factorial Design of Experiments (DoE)** is a '
#                        'systematic method used to evaluate the effects of '
#                        'multiple factors on a response variable. It allows '
#                        'researchers to understand how different variables '
#                        'interact with each other and influence outcomes. The '
#                        'key aspects of factorial DoE include:\n'
#                        '\n'
#                        '1. **Full Factorial Design**: This involves testing '
#                        'all possible combinations of factors at different '
#                        'levels. For example, if there are two factors, each at '
#                        'two levels, a full factorial design would require four '
#                        'experiments (2^2).\n'
#                        '\n'
#                        '2. **Fractional Factorial Design**: When the number of '
#                        'experiments becomes too large, a fractional factorial '
#                        'design can be used to test only a subset of the '
#                        'combinations, which can still provide valuable '
#                        'insights while reducing resource requirements.\n'
#                        '\n'
#                        '3. **Performance Metrics**: In evaluating factorial '
#                        'DoE projects, performance metrics such as response '
#                        'time, yield, quality, and cost-effectiveness are '
#                        'crucial. These metrics help in assessing the impact of '
#                        'different factors and in making informed decisions '
#                        'about process improvements.\n'
#                        '\n'
#                        '4. **Analysis of Variance (ANOVA)**: This statistical '
#                        'method is often used in conjunction with factorial DoE '
#                        'to determine the significance of the factors and their '
#                        'interactions.\n'
#                        '\n'
#                        '5. **Applications**: Factorial DoE is widely used in '
#                        'various fields, including manufacturing, agriculture, '
#                        'and pharmaceuticals, to optimize processes and improve '
#                        'product quality.\n'
#                        '\n'
#                        'In practical applications, factorial DoE can be '
#                        'implemented using statistical software that allows for '
#                        'the design, execution, and analysis of experiments '
#                        'efficiently.\n'
#                        '\n'
#                        'If you need further details or specific examples '
#                        'related to factorial DoE, please let me know!'},
#  {'abilities': ['A3', 'A4'],
#   'learning_outcome': 'Define the scope and execute fractional factorial DoE '
#                       'projects using problem-solving techniques.',
#   'retrieved_content': 'No specific content related to the Learning Outcome of '
#                        'defining the scope and executing fractional factorial '
#                        'Design of Experiments (DoE) projects using '
#                        'problem-solving techniques was found in the provided '
#                        'documents. \n'
#                        '\n'
#                        '### General Summary of Fractional Factorial DoE:\n'
#                        'Fractional factorial design is a statistical method '
#                        'used in experiments to evaluate multiple factors '
#                        'simultaneously while reducing the number of '
#                        'experimental runs. This approach is particularly '
#                        'useful when resources are limited or when the number '
#                        'of factors is large. \n'
#                        '\n'
#                        '1. **Defining Project Scope**: \n'
#                        '   - Identify the key factors that influence the '
#                        'outcome of the experiment.\n'
#                        '   - Determine the levels of each factor to be '
#                        'tested.\n'
#                        '   - Establish the objectives of the experiment and '
#                        'the expected outcomes.\n'
#                        '\n'
#                        '2. **Executing the Project**:\n'
#                        '   - Develop a project plan that outlines the '
#                        'experimental design, including the selection of a '
#                        'fractional factorial design matrix.\n'
#                        '   - Conduct the experiments according to the '
#                        'established plan, ensuring that all factors are varied '
#                        'systematically.\n'
#                        '   - Analyze the results to identify significant '
#                        'factors and interactions.\n'
#                        '\n'
#                        '### Example Code for Fractional Factorial Design:\n'
#                        '```python\n'
#                        'import pandas as pd\n'
#                        'from pyDOE import fracfact\n'
#                        '\n'
#                        '# Define the factors and levels\n'
#                        'factors = 3  # Number of factors\n'
#                        'levels = 2   # Levels for each factor (e.g., high and '
#                        'low)\n'
#                        '\n'
#                        '# Generate a fractional factorial design\n'
#                        "design = fracfact('a b c -a b c')\n"
#                        '\n'
#                        '# Convert to DataFrame for better visualization\n'
#                        "design_df = pd.DataFrame(design, columns=['Factor A', "
#                        "'Factor B', 'Factor C'])\n"
#                        'print(design_df)\n'
#                        '```\n'
#                        '\n'
#                        'This code snippet demonstrates how to create a '
#                        'fractional factorial design using the `pyDOE` library '
#                        'in Python, which can be useful for planning '
#                        'experiments efficiently.\n'
#                        '\n'
#                        'If you need more specific information or examples '
#                        'related to fractional factorial DoE, please provide '
#                        'additional context or details.'},
#  {'abilities': ['A5', 'A6'],
#   'learning_outcome': 'Evaluate the effectiveness of DoE projects and '
#                       'recommend follow-up actions.',
#   'retrieved_content': 'No specific content related to the Learning Outcome of '
#                        'evaluating the effectiveness of DoE projects and '
#                        'recommending follow-up actions was found in the '
#                        'provided documents. \n'
#                        '\n'
#                        'However, a general summary of the topic "Screening, '
#                        'Modeling and Optimizing DoE" can be provided:\n'
#                        '\n'
#                        '**Summary of Screening, Modeling, and Optimizing '
#                        'DoE:**\n'
#                        'Design of Experiments (DoE) is a systematic method '
#                        'used to determine the relationship between factors '
#                        'affecting a process and the output of that process. '
#                        'The screening phase involves identifying the most '
#                        'significant factors that influence the outcome. '
#                        'Modeling is used to understand the relationships '
#                        'between these factors and the response variable, often '
#                        'employing statistical techniques to create predictive '
#                        'models. Optimization aims to find the best conditions '
#                        'for the desired outcome by adjusting the significant '
#                        'factors identified during screening.\n'
#                        '\n'
#                        'In evaluating the effectiveness of DoE projects, one '
#                        'would assess whether the project objectives were met, '
#                        'using metrics such as response improvement, cost '
#                        'reduction, or process efficiency. Follow-up actions '
#                        'could include further experimentation, adjustments to '
#                        'the process based on findings, or implementing changes '
#                        'in production based on the optimized conditions.\n'
#                        '\n'
#                        'If you have any other specific queries or need '
#                        'information on a different topic, feel free to ask!'}]

# %%
user_proxy_agent = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    max_consecutive_auto_reply=5,
    is_termination_msg=lambda msg: msg.get("content", "") and "TERMINATE" in msg["content"],
    code_execution_config={"work_dir": "output", "use_docker": False, "response_format": {"type": "json_object"}}
)

# %%
qa_generation_agent = AssistantAgent(
    name="question_answer_generator",
    system_message=f"""
    You are an expert educator in '{extracted_data.course_title}'. You will create scenario-based practical performance assessment (PPA) question-answer pairs based on course data.
    The data will include:
    - A scenario
    - Retrieved content aligned with learning outcomes and abilities

    ### Instructions:
    1. Use the provided scenario and retrieved content to generate **one practical question-answer pair per learning outcome.**

    2. **Question Requirements:**
    - Each question must describe a hands-on task or practical activity related to the scenario.
    - Ensure the task can be performed based on the scenario's context without assuming learners have additional information.
    - For coding courses, specify programming tasks with clear starting points. For non-coding courses, describe actions such as planning, decision-making, evaluating data, or implementing processes.
    - Ensure the question ends with "Take snapshots of your commands at each step and paste them below."

    3. **Answer Requirements:**
    - **Provide the exact solutions** (e.g., final code, commands, outputs, or tangible deliverables) rather than describing how to capture the snapshots.
    - If there is relevant text or direct quotes from the retrieved content, include them verbatim with proper citations, for example, "(Source: [retrieved_content_reference])".
    - Each answer should contain only the final (correct) output or solution. Avoid step-by-step instructions on capturing or documenting the process.

    4. Structure the final output in valid JSON with the following format:
    
    ```json
    {{
        "course_title": "<course_title_here>",
        "duration": "<assessment_duration_here>",
        "scenario": "<scenario_here>",
        "questions": [
            {{
                "question_statement": "<question_text>",
                "answer": ["<list_of exact final solutions or outputs>"],
                "ability_id": ["<list_of_ability_ids>"]
            }},
            ...
        ]
    }}
    ```
    5. Ensure the generated practical tasks align strictly with the retrieved content and abilities. If there is relevant text or direct quotes from the retrieved content, include them verbatim. Use a format like “(Source: [retrieved_content_reference])” where needed.
    6. Return the JSON between triple backticks followed by 'TERMINATE'.
    """,
    llm_config=llm_config,
)
# Out:
# [autogen.oai.client: 12-24 12:03:50] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.

# %% [markdown]
# ## Experimental Retrieval with Citation
#
# In this section, we perform experimental retrieval of content with proper citations. The process involves the following steps:
#
# 1. **Define Retrieval Prompt**:
#     - Create a prompt to retrieve content aligned with specific learning outcomes and abilities.
#
# 2. **Execute Retrieval**:
#     - Use the query engine to retrieve relevant content based on the defined prompt.
#
# 3. **Cite Sources**:
#     - Ensure that all retrieved content includes proper citations to the original sources.
#
# 4. **Output Format**:
#     - Structure the retrieved content and citations in a clear and organized format for easy reference and validation.
#
# This approach ensures that the retrieved content is both relevant and properly attributed, maintaining academic integrity and providing clear references for further study.

# %%
qa_generation_agent = AssistantAgent(
    name="question_answer_generator",
    system_message=f"""
    You are an expert educator in '{extracted_data.course_title}'. You will create scenario-based practical performance assessment (PPA) question-answer pairs based on course data.
    The data will include:
    - A scenario
    - Retrieved content aligned with learning outcomes and abilities

    ### Instructions:
    1. Use the provided scenario and retrieved content to generate **one practical question-answer pair per learning outcome.**

    2. **Question Requirements:**
    - Each question must describe a hands-on task or practical activity related to the scenario.
    - Ensure the task can be performed based on the scenario's context without assuming learners have additional information.
    - For coding courses, specify programming tasks with clear starting points. For non-coding courses, describe actions such as planning, decision-making, evaluating data, or implementing processes.
    - Ensure the question ends with "Take snapshots of your commands at each step and paste them below."

    3. **Answer Requirements:**
    - The answer must explicitly describe the step-by-step practical actions the learner must perform to produce the snapshots.
    - The steps must:
        - Clearly specify **what learners should do** (e.g., commands to execute, actions to take, or configurations to make).
        - **Describe the output or results** learners will observe and capture in their snapshots.
        - Align strictly with the question's task and scenario.
    - For coding tasks:
        - Include steps such as writing and executing code, along with descriptions of expected outputs or configurations.
        - Example: "The snapshot should include: (1) A screenshot of the Python code editor with your script, (2) The terminal output showing the API response, and (3) A log of any errors encountered during execution."
    - For management or industry tasks:
        - Include steps for creating tangible deliverables such as project plans, reports, or visualizations.
        - Example: "The snapshot should include: (1) A screenshot of the completed project timeline, (2) A visualization of key performance indicators (e.g., chart or table), and (3) A summary report of key decisions."
    - Avoid theoretical explanations, general advice, or abstract concepts. The answer must focus exclusively on describing concrete, observable outputs aligned with the scenario's context.

    4. Structure the final output in valid JSON with the following format:
    
json
    {{
        "course_title": "<course_title_here>",
        "duration": "<assessment_duration_here>",
        "scenario": "<scenario_here>",
        "questions": [
            {{
                "question_statement": "<question_text>",
                "answer": ["<list_of_practical_steps describing the snapshot answer>"],
                "ability_id": ["<list_of_ability_ids>"]
            }},
            ...
        ]
    }}

    5. Ensure the generated practical tasks align strictly with the retrieved content and abilities. 
       - **If there is relevant text or direct quotes from the retrieved content, include them verbatim.** 
       - If you include a direct citation, use a format like "(Source: [retrieved_content_reference])" to clearly indicate its origin.
    6. Return the JSON between triple backticks followed by 'TERMINATE'.
    """,
    llm_config=llm_config,
)
# Out:
# [autogen.oai.client: 12-23 16:58:47] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# user_proxy (to question_answer_generator):
#
#
#         Please generate the questions and answer using the following course title:'Develop Artificial Intelligence and Large Language Model (LLM) Applications with Google Gemini', assessment_duration:'', scenario: '**Scenario:**
#
# TechSolutions, a mid-sized technology firm specializing in software development, is facing challenges in optimizing its customer support operations. The company has recently integrated a Generative AI (GAI) system powered by Google Gemini to enhance its customer interaction capabilities. However, the management is unsure about the effectiveness of the AI in handling customer queries and its impact on overall operational efficiency. As part of a practical performance assessment, learners are tasked with analyzing the range of LLM applications utilized by TechSolutions, identifying their strengths and limitations in the context of customer support. They must establish the design of the Google Gemini GAI system, assess its feasibility in improving response times and customer satisfaction, and evaluate the performance effectiveness of the implemented Retrieval Augmented Generation (RAG) processes. Additionally, learners will analyze the algorithms used in the AI applications to determine their correlation with operational efficiency and propose improvements to the engineering processes based on their findings.
#
# **Tasks:**
# 1. Analyze the LLM applications used in customer support and identify their industrial use cases.
# 2. Establish the design of the Google Gemini GAI system and assess its impact on engineering processes.
# 3. Develop a feasibility report on the AI applications in enhancing customer support.
# 4. Evaluate the performance effectiveness of the RAG processes implemented in the customer support system.' and topic contents:[{'learning_outcome': 'Analyze the range of LLM applications using Generative AI (GAI) and identify their industrial use cases.', 'abilities': ['A1', 'A3'], 'retrieved_content': 'To align with the Learning Outcome of analyzing the range of LLM applications using Generative AI (GAI) and identifying their industrial use cases, the following relevant content has been retrieved:\n\n### Summary of Relevant Content:\nLarge Language Models (LLMs) like OpenAI\'s GPT-4 and Google Gemini have a wide array of applications across various industries. These applications leverage the capabilities of Generative AI to enhance processes, improve efficiency, and provide innovative solutions. The identified use cases include:\n\n1. **Content Creation and Assistance**: Automating the generation of written content for marketing, blogs, and social media.\n2. **Customer Support and Chatbots**: Utilizing LLMs to provide real-time assistance and automate responses to customer inquiries.\n3. **Language Translation and Localization**: Enhancing communication across different languages by providing accurate translations.\n4. **Educational Tools**: Offering personalized learning experiences and tutoring through interactive AI.\n5. **Business Intelligence and Analytics**: Analyzing data and generating insights to support decision-making processes.\n6. **Healthcare Support**: Assisting in patient care through automated responses and information retrieval.\n7. **Legal and Compliance Assistance**: Streamlining document review and compliance checks using AI-driven analysis.\n\nThese applications demonstrate the strengths of LLMs in processing and generating human-like text, while also highlighting potential limitations such as the need for large datasets and the risk of generating biased or inaccurate information.\n\n### Extracted Segments:\n1. **Opportunities of LLM Applications**:\n   - "Content Creation and Assistance"\n   - "Customer Support and Chatbots"\n   - "Language Translation and Localization"\n   - "Educational Tools"\n   - "Business Intelligence and Analytics"\n   - "Healthcare Support"\n   - "Legal and Compliance Assistance"\n\n2. **Use Cases of GAI in Various Industries**:\n   - **Finance**: "Automated Financial Reporting", "Risk Assessment and Analysis", "Fraud Detection and Prevention".\n   - **Marketing**: "Content Creation", "Market Research Analysis", "Customer Sentiment Analysis".\n   - **Education**: "Personalized Learning Assistance", "Grading and Feedback Automation".\n   - **Healthcare**: "Drug discovery and development", "Personalized medicine and treatment optimization".\n\nThese segments provide a clear view of the applications and use cases of LLMs in various sectors, supporting the analysis of their strengths and limitations.\n\n### Document References:\n- **Overview of Large Language Model (LLM)**: Page 17\n- **Use Cases of GAI in Finance**: Page 19\n- **Use Cases of GAI in Marketing**: Page 20\n- **Use Cases of GAI in Education**: Page 21\n- **Use Cases of GAI in Healthcare**: Page 22\n- **Use Cases of GAI in Legal**: Page 23\n- **Use Cases of GAI in HR**: Page 24\n- **Use Cases of GAI in eCommerce**: Page 25\n\nThis content directly supports the Learning Outcome and associated abilities by providing a comprehensive overview of LLM applications and their industrial use cases.'}, {'learning_outcome': 'Establish Google Gemini GAI designs and assess improvements on engineering processes.', 'abilities': ['A2', 'A6'], 'retrieved_content': 'The content relevant to the Learning Outcome of establishing Google Gemini GAI designs and assessing improvements on engineering processes, particularly focusing on the associated abilities A2 and A6, includes practical insights into the design and implementation of multimodal prompting with Google Gemini LLM. \n\n### Retrieved Content:\n1. **Multimodal Prompting with Google ...
#         Phrase your question in accordance with the Bloom's Taxonomy Level: 3
#         Bloom's Taxonomy Level Information:
#             Level 1: Remembering
#             Level 2: Understanding
#             Level 3: Applying
#             Level 4: Analyzing
#             Level 5: Evaluating
#             Level 6: Creating
#         Ensure the question ends with "Take snapshots of your commands at each step and paste them below."
#         Ensure the answer begins with "The snapshot should include: " and specifies only practical steps to test hands-on skills without any writing or documenting.
#         RETURN 'TERMINATE' once the generation is done.
#
#
# --------------------------------------------------------------------------------
# question_answer_generator (to user_proxy):
#
# ```json
# {
#     "course_title": "Develop Artificial Intelligence and Large Language Model (LLM) Applications with Google Gemini",
#     "duration": "",
#     "scenario": "**Scenario:** TechSolutions, a mid-sized technology firm specializing in software development, is facing challenges in optimizing its customer support operations. The company has recently integrated a Generative AI (GAI) system powered by Google Gemini to enhance its customer interaction capabilities. However, the management is unsure about the effectiveness of the AI in handling customer queries and its impact on overall operational efficiency. As part of a practical performance assessment, learners are tasked with analyzing the range of LLM applications utilized by TechSolutions, identifying their strengths and limitations in the context of customer support. They must establish the design of the Google Gemini GAI system, assess its feasibility in improving response times and customer satisfaction, and evaluate the performance effectiveness of the implemented Retrieval Augmented Generation (RAG) processes. Additionally, learners will analyze the algorithms used in the AI applications to determine their correlation with operational efficiency and propose improvements to the engineering processes based on their findings.",
#     "questions": [
#         {
#             "question_statement": "Analyze the LLM applications used in customer support. List at least three industrial use cases and describe their strengths and limitations. Take snapshots of your commands at each step and paste them below.",
#             "answer": [
#                 "The snapshot should include: (1) A screenshot of your document where you list the industrial use cases, including specific strengths and limitations, (2) Evidence of data sources used to compile this information, and (3) Any tools used for the analysis."
#             ],
#             "ability_id": ["A1", "A3"]
#         },
#         {
#             "question_statement": "Develop the design outline for the Google Gemini GAI system focusing on multimodal prompting. Demonstrate the setup process by providing sample code and invoking it. Take snapshots of your commands at each step and paste them below.",
#             "answer": [
#                 "The snapshot should include: (1) A screenshot of your code editor with the multimodal prompting Python code, (2) The terminal output showing the response from the Google Gemini model, (3) Any configuration settings you adjusted in Google AI Studio."
#             ],
#             "ability_id": ["A2", "A6"]
#         },
#         {
#             "question_statement": "Create a feasibility report on the AI applications in enhancing customer support by evaluating their specific functionalities and anticipated outcomes. Take snapshots of your commands at each step and paste them below.",
#             "answer": [
#                 "The snapshot should include: (1) A screenshot of the completed feasibility report with defined functionalities, (2) Any relevant graphs or charts that illustrate the anticipated outcomes, and (3) A metadata table highlighting each application's strengths and challenges."
#             ],
#             "ability_id": ["A5"]
#         },
#         {
#             "question_statement": "Evaluate the performance effectiveness of the implemented Retrieval Augmented Generation (RAG) processes by executing a series of queries and recording the response quality. Take snapshots of your commands at each step and paste them below.",
#             "answer": [
#                 "The snapshot should include: (1) A screenshot of the code for loading documents and executing queries using the RAG processes, (2) The output generated from the queries, showing accurate and relevant responses, and (3) Notes on any discrepancies or issues encountered during testing."
#             ],
#             "ability_id": ["A4"]
#         }
#     ]
# }
# ```
# TERMINATE
#
# --------------------------------------------------------------------------------
# ('CONTEXT JSON MAPPING: \n'
#  '\n'
#  "{'course_title': 'Develop Artificial Intelligence and Large Language Model "
#  "(LLM) Applications with Google Gemini', 'duration': '', 'scenario': "
#  "'**Scenario:** TechSolutions, a mid-sized technology firm specializing in "
#  'software development, is facing challenges in optimizing its customer '
#  'support operations. The company has recently integrated a Generative AI '
#  '(GAI) system powered by Google Gemini to enhance its customer interaction '
#  'capabilities. However, the management is unsure about the effectiveness of '
#  'the AI in handling customer queries and its impact on overall operational '
#  'efficiency. As part of a practical performance assessment, learners are '
#  'tasked with analyzing the range of LLM applications utilized by '
#  'TechSolutions, identifying their strengths and limitations in the context of '
#  'customer support. They must establish the design of the Google Gemini GAI '
#  'system, assess its feasibility in improving response times and customer '
#  'satisfaction, and evaluate the performance effectiveness of the implemented '
#  'Retrieval Augmented Generation (RAG) processes. Additionally, learners will '
#  'analyze the algorithms used in the AI applications to determine their '
#  'correlation with operational efficiency and propose improvements to the '
#  "engineering processes based on their findings.', 'questions': "
#  "[{'question_statement': 'Analyze the LLM applications used in customer "
#  'support. List at least three industrial use cases and describe their '
#  'strengths and limitations. Take snapshots of your commands at each step and '
#  "paste them below.', 'answer': ['The snapshot should include: (1) A "
#  'screenshot of your document where you list the industrial use cases, '
#  'including specific strengths and limitations, (2) Evidence of data sources '
#  'used to compile this information, and (3) Any tools used for the '
#  "analysis.'], 'ability_id': ['A1', 'A3']}, {'question_statement': 'Develop "
#  'the design outline for the Google Gemini GAI system focusing on multimodal '
#  'prompting. Demonstrate the setup process by providing sample code and '
#  'invoking it. Take snapshots of your commands at each step and paste them '
#  "below.', 'answer': ['The snapshot should include: (1) A screenshot of your "
#  'code editor with the multimodal prompting Python code, (2) The terminal '
#  'output showing the response from the Google Gemini model, (3) Any '
#  "configuration settings you adjusted in Google AI Studio.'], 'ability_id': "
#  "['A2', 'A6']}, {'question_statement': 'Create a feasibility report on the AI "
#  'applications in enhancing customer support by evaluating their specific '
#  'functionalities and anticipated outcomes. Take snapshots of your commands at '
#  'each step and paste them below.\', \'answer\': ["The snapshot should '
#  'include: (1) A screenshot of the completed feasibility report with defined '
#  'functionalities, (2) Any relevant graphs or charts that illustrate the '
#  'anticipated outcomes, and (3) A metadata table highlighting each '
#  'application\'s strengths and challenges."], \'ability_id\': [\'A5\']}, '
#  "{'question_statement': 'Evaluate the performance effectiveness of the "
#  'implemented Retrieval Augmented Generation (RAG) processes by executing a '
#  'series of queries and recording the response quality. Take snapshots of your '
#  "commands at each step and paste them below.', 'answer': ['The snapshot "
#  'should include: (1) A screenshot of the code for loading documents and '
#  'executing queries using the RAG processes, (2) The output generated from the '
#  'queries, showing accurate and relevant responses, and (3) Notes on any '
#  "discrepancies or issues encountered during testing.'], 'ability_id': "
#  "['A4']}]}")
# ("CS cost: {'usage_including_cached_inference': {'total_cost': "
#  "0.0015412499999999997, 'gpt-4o-mini-2024-07-18': {'cost': "
#  "0.0015412499999999997, 'prompt_tokens': 6931, 'completion_tokens': 836, "
#  "'total_tokens': 7767}}, 'usage_excluding_cached_inference': {'total_cost': "
#  "0.0015412499999999997, 'gpt-4o-mini-2024-07-18': {'cost': "
#  "0.0015412499999999997, 'prompt_tokens': 6931, 'completion_tokens': 836, "
#  "'total_tokens': 7767}}}")

# %%
assessment_duration = ""
for assessment in extracted_data.assessments:
    if "PP" in assessment.code:
        assessment_duration = assessment.duration

with Cache.disk() as cache:
    chat_result = user_proxy_agent.initiate_chat(
        qa_generation_agent,
        message=f"""
        Please generate the questions and answer using the following course title:'{extracted_data.course_title}', assessment_duration:'{assessment_duration}', scenario: '{scenario}' and topic contents:{retrieved_content}
        Phrase your question in accordance with the Bloom's Taxonomy Level: {extracted_data.tsc_proficiency_level}
        Bloom's Taxonomy Level Information:
            Level 1: Remembering
            Level 2: Understanding
            Level 3: Applying
            Level 4: Analyzing
            Level 5: Evaluating
            Level 6: Creating
        Ensure the question ends with "Take snapshots of your commands at each step and paste them below."
        Ensure the answer begins with "The snapshot should include: " and specifies only practical steps to test hands-on skills without any writing or documenting.
        RETURN 'TERMINATE' once the generation is done.
        """,
        summary_method="reflection_with_llm",
        cache=cache,
)
try:
    last_message_content = chat_result.chat_history[-1].get("content", "")
    if not last_message_content:
        print("No content found in the agent's last message.")
    last_message_content = last_message_content.strip()
    json_pattern = re.compile(r'```json\s*(\{.*?\})\s*```', re.DOTALL)
    json_match = json_pattern.search(last_message_content)
    if json_match:
        json_str = json_match.group(1)
        context = json.loads(json_str)
        pprint.pprint(f"CONTEXT JSON MAPPING: \n\n{context}")
    pprint.pprint(f"CS cost: {chat_result.cost}")
except json.JSONDecodeError as e:
    print(f"Error parsing context JSON: {e}")
# Out:
# user_proxy (to question_answer_generator):
#
#
#         Please generate the questions and answer using the following course title:'Practical Design of Experiment (DoE) for Engineers and Researchers', assessment_duration:'', scenario: '**Scenario:**
#
# InnovateTech, a mid-sized manufacturing company specializing in electronic components, is experiencing a decline in product quality and an increase in production costs. The management has identified that several factors, including machine calibration, raw material quality, and operator training, may be influencing the performance of their production processes. To address these issues, the company has decided to implement a Design of Experiments (DoE) approach to systematically analyze these interactions. As part of a team of engineers and researchers, you are tasked with analyzing the process interactions to identify key factors affecting performance, selecting suitable factorial DoE projects based on relevant performance metrics, defining the scope of the projects, and executing fractional factorial DoE experiments. Additionally, you will evaluate the effectiveness of these experiments and recommend follow-up actions to improve product quality and reduce costs.
#
# **Assessment Tasks:**
# 1. Analyze the interactions between identified factors affecting production quality.
# 2. Select appropriate factorial DoE projects based on performance metrics such as defect rates and production efficiency.
# 3. Define the project scope, including the number of hours required for each experiment based on business needs.
# 4. Execute the DoE projects according to the established project plan.
# 5. Evaluate the effectiveness of the DoE projects against the defined objectives and recommend actionable follow-up steps to management.' and topic contents:[{'learning_outcome': 'Analyze process interactions to characterize key factors influencing performance in Design of Experiments (DoE).', 'abilities': ['A1'], 'retrieved_content': 'No specific content related to the Learning Outcome of analyzing process interactions to characterize key factors influencing performance in Design of Experiments (DoE) was found in the provided documents. \n\nHere is a general summary of the topic:\n\n**Design of Experiments (DoE)** is a statistical approach used to plan, conduct, and analyze controlled tests to evaluate the factors that may influence a particular outcome. The fundamental goal of DoE is to identify the relationships between factors affecting a process and the output of that process. By systematically varying the input factors and observing the resulting changes in output, researchers can determine which factors are significant and how they interact with each other.\n\nKey aspects of DoE include:\n- **Factorial Designs**: These designs allow for the evaluation of multiple factors simultaneously, providing insights into interactions between factors.\n- **Randomization**: This helps to eliminate bias and ensures that the results are generalizable.\n- **Replication**: Repeating experiments to ensure reliability and accuracy of results.\n- **Analysis of Variance (ANOVA)**: A statistical method used to determine if there are significant differences between the means of different groups.\n\nIn practice, DoE can be applied in various fields such as manufacturing, agriculture, and pharmaceuticals to optimize processes and improve product quality.\n\nIf you need further information or specific examples related to DoE, please let me know!'}, {'learning_outcome': 'Select suitable factorial DoE projects by evaluating relevant performance metrics.', 'abilities': ['A2'], 'retrieved_content': 'No specific content directly aligns with the Learning Outcome of selecting suitable factorial DoE projects by evaluating relevant performance metrics, nor does it correspond to the associated ability of selecting appropriate new or continuous process integration improvement projects. \n\nHere is a general summary of the topic of Factorial Design of Experiments (DoE):\n\n**Factorial Design of Experiments (DoE)** is a systematic method used to evaluate the effects of multiple factors on a response variable. It allows researchers to understand how different variables interact with each other and influence outcomes. The key aspects of factorial DoE include:\n\n1. **Full Factorial Design**: This involves testing all possible combinations of factors at different levels. For example, if there are two factors, each at two levels, a full factorial design would require four experiments (2^2).\n\n2. **Fractional Factorial Design**: When the number of experiments becomes too large, a fractional factorial design can be used to test only a subset of the combinations, which can still provide valuable insights while reducing resource requirements.\n\n3. **Performance Metrics**: In evaluating factorial DoE projects, performance metrics such as response time, yield, quality, and cost-effectiveness are crucial. These metrics help in assessing the impact of different factors and in making informed decisions about process improvements.\n\n4. **Analysis of Variance (ANOVA)**: This statistical method is often used in conjunction with factorial DoE to determine the significance of the factors and their interactions.\n\n5. **Applications**: Factorial DoE is widely used in various fields, including manufacturing, agriculture, and pharmaceuticals, to optimize processes and improve product quality.\n\nIn practical applications, factorial DoE can be implemented using statistical software that allows for the design, execution, and analysis of experiments efficiently.\n\nIf you need f ...
#         Phrase your question in accordance with the Bloom's Taxonomy Level: 5
#         Bloom's Taxonomy Level Information:
#             Level 1: Remembering
#             Level 2: Understanding
#             Level 3: Applying
#             Level 4: Analyzing
#             Level 5: Evaluating
#             Level 6: Creating
#         Ensure the question ends with "Take snapshots of your commands at each step and paste them below."
#         Ensure the answer begins with "The snapshot should include: " and specifies only practical steps to test hands-on skills without any writing or documenting.
#         RETURN 'TERMINATE' once the generation is done.
#
#
# --------------------------------------------------------------------------------
# question_answer_generator (to user_proxy):
#
# ```json
# {
#     "course_title": "Practical Design of Experiment (DoE) for Engineers and Researchers",
#     "duration": "",
#     "scenario": "InnovateTech, a mid-sized manufacturing company specializing in electronic components, is experiencing a decline in product quality and an increase in production costs. The management has identified that several factors, including machine calibration, raw material quality, and operator training, may be influencing the performance of their production processes. To address these issues, the company has decided to implement a Design of Experiments (DoE) approach to systematically analyze these interactions. As part of a team of engineers and researchers, you are tasked with analyzing the process interactions to identify key factors affecting performance, selecting suitable factorial DoE projects based on relevant performance metrics, defining the scope of the projects, and executing fractional factorial DoE experiments. Additionally, you will evaluate the effectiveness of these experiments and recommend follow-up actions to improve product quality and reduce costs.",
#     "questions": [
#         {
#             "question_statement": "Analyze the interactions between machine calibration, raw material quality, and operator training affecting production quality at InnovateTech. Use a factorial design approach and apply Analysis of Variance (ANOVA) to determine significant interactions. Take snapshots of your commands at each step and paste them below.",
#             "answer": ["The snapshot should include: The ANOVA table highlighting significant interactions between factors at a 5% significance level."],
#             "ability_id": ["A1"]
#         },
#         {
#             "question_statement": "Select appropriate factorial DoE projects by evaluating defect rates and production efficiency metrics. Identify at least two promising projects that could improve these metrics at InnovateTech. Take snapshots of your commands at each step and paste them below.",
#             "answer": ["The snapshot should include: The selection criteria table showing defect rates and production efficiency improvements from selected projects."],
#             "ability_id": ["A2"]
#         },
#         {
#             "question_statement": "Define the project scope for executing fractional factorial DoE given the identified factors at InnovateTech. Include the number of hours required and key factor levels to be tested. Then, execute a fractional factorial design using Python. Take snapshots of your commands at each step and paste them below.",
#             "answer": ["The snapshot should include: Python output showing the fractional factorial design matrix and project hours estimation."],
#             "ability_id": ["A3", "A4"]
#         },
#         {
#             "question_statement": "Evaluate the effectiveness of the completed DoE projects using response improvement metrics. Provide recommendations for follow-up actions to management to enhance product quality and reduce costs. Take snapshots of your commands at each step and paste them below.",
#             "answer": ["The snapshot should include: Evaluation report summarizing response improvement metrics and a list of recommended actions."],
#             "ability_id": ["A5", "A6"]
#         }
#     ]
# }
# ```
# TERMINATE
#
# --------------------------------------------------------------------------------
# ('CONTEXT JSON MAPPING: \n'
#  '\n'
#  "{'course_title': 'Practical Design of Experiment (DoE) for Engineers and "
#  "Researchers', 'duration': '', 'scenario': 'InnovateTech, a mid-sized "
#  'manufacturing company specializing in electronic components, is experiencing '
#  'a decline in product quality and an increase in production costs. The '
#  'management has identified that several factors, including machine '
#  'calibration, raw material quality, and operator training, may be influencing '
#  'the performance of their production processes. To address these issues, the '
#  'company has decided to implement a Design of Experiments (DoE) approach to '
#  'systematically analyze these interactions. As part of a team of engineers '
#  'and researchers, you are tasked with analyzing the process interactions to '
#  'identify key factors affecting performance, selecting suitable factorial DoE '
#  'projects based on relevant performance metrics, defining the scope of the '
#  'projects, and executing fractional factorial DoE experiments. Additionally, '
#  'you will evaluate the effectiveness of these experiments and recommend '
#  "follow-up actions to improve product quality and reduce costs.', "
#  "'questions': [{'question_statement': 'Analyze the interactions between "
#  'machine calibration, raw material quality, and operator training affecting '
#  'production quality at InnovateTech. Use a factorial design approach and '
#  'apply Analysis of Variance (ANOVA) to determine significant interactions. '
#  "Take snapshots of your commands at each step and paste them below.', "
#  "'answer': ['The snapshot should include: The ANOVA table highlighting "
#  "significant interactions between factors at a 5% significance level.'], "
#  "'ability_id': ['A1']}, {'question_statement': 'Select appropriate factorial "
#  'DoE projects by evaluating defect rates and production efficiency metrics. '
#  'Identify at least two promising projects that could improve these metrics at '
#  'InnovateTech. Take snapshots of your commands at each step and paste them '
#  "below.', 'answer': ['The snapshot should include: The selection criteria "
#  'table showing defect rates and production efficiency improvements from '
#  "selected projects.'], 'ability_id': ['A2']}, {'question_statement': 'Define "
#  'the project scope for executing fractional factorial DoE given the '
#  'identified factors at InnovateTech. Include the number of hours required and '
#  'key factor levels to be tested. Then, execute a fractional factorial design '
#  'using Python. Take snapshots of your commands at each step and paste them '
#  "below.', 'answer': ['The snapshot should include: Python output showing the "
#  "fractional factorial design matrix and project hours estimation.'], "
#  "'ability_id': ['A3', 'A4']}, {'question_statement': 'Evaluate the "
#  'effectiveness of the completed DoE projects using response improvement '
#  'metrics. Provide recommendations for follow-up actions to management to '
#  'enhance product quality and reduce costs. Take snapshots of your commands at '
#  "each step and paste them below.', 'answer': ['The snapshot should include: "
#  'Evaluation report summarizing response improvement metrics and a list of '
#  "recommended actions.'], 'ability_id': ['A5', 'A6']}]}")
# ("CS cost: {'usage_including_cached_inference': {'total_cost': 0.01937, "
#  "'gpt-4o-2024-08-06': {'cost': 0.01937, 'prompt_tokens': 4928, "
#  "'completion_tokens': 705, 'total_tokens': 5633}}, "
#  "'usage_excluding_cached_inference': {'total_cost': 0.01937, "
#  "'gpt-4o-2024-08-06': {'cost': 0.01937, 'prompt_tokens': 4928, "
#  "'completion_tokens': 705, 'total_tokens': 5633}}}")

# %%
from docxtpl import DocxTemplate
import tempfile

def generate_documents(context: dict, assessment_type: str, output_dir: str) -> dict:
    """
    Generate the question paper and answer paper for the given context and type.

    Parameters:
    - context (dict): The data for the assessment (course title, type, questions, etc.).
    - assessment_type (str): The assessment type (e.g., 'Ability-based', 'Knowledge-based').
    - output_dir (str): Directory where the generated documents will be saved.

    Returns:
    - dict: Paths to the generated documents (question and answer papers).
    """
    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)
    # Load templates
    TEMPLATES = {
        "QUESTION": f"C:/Users/dljh1/Documents/courseware_autogen/Assessment/Templates/(Template) {assessment_type} - Course Title - v1.docx",
        "ANSWER": f"C:/Users/dljh1/Documents/courseware_autogen/Assessment/Templates/(Template) Answer to {assessment_type} - Course Title - v1.docx"
        }

    qn_template = TEMPLATES["QUESTION"]
    ans_template = TEMPLATES["ANSWER"]
    question_doc = DocxTemplate(qn_template)
    answer_doc = DocxTemplate(ans_template)
    
    # Prepare context for the question paper by creating a copy of the context without answers
    question_context = {
        **context,
        "questions": [
            {**question, "answer": None} for question in context.get("questions", [])
        ]
    }


    # Render both templates
    answer_doc.render(context)  # Render with answers
    question_doc.render(question_context)  # Render without answers

    # Create temporary files for the question and answer documents
    question_tempfile = tempfile.NamedTemporaryFile(
        delete=False, suffix=f"_{assessment_type}_Questions.docx"
    )
    answer_tempfile = tempfile.NamedTemporaryFile(
        delete=False, suffix=f"_{assessment_type}_Answers.docx"
    )

    # Save the rendered documents to the temporary files
    question_doc.save(question_tempfile.name)
    answer_doc.save(answer_tempfile.name)

    return {
        "ASSESSMENT_TYPE": assessment_type,
        "QUESTION": question_tempfile.name,
        "ANSWER": answer_tempfile.name
    }

# %%
files = generate_documents(
    context=context, 
    assessment_type="PP",
    output_dir="output"
)

print(f"Generated documents: {files}")
# Out:
# Generated documents: {'ASSESSMENT_TYPE': 'PP', 'QUESTION': 'C:\\Users\\dljh1\\AppData\\Local\\Temp\\tmpos07pia9_PP_Questions.docx', 'ANSWER': 'C:\\Users\\dljh1\\AppData\\Local\\Temp\\tmpyj4nc5bw_PP_Answers.docx'}

# %%
# Generate a detailed scenario for the case study
def generate_case_study_scenario(data: FacilitatorGuideExtraction, engine) -> str:
    """
    Generates a concise, realistic scenario for the case study.
    Args:
        course_title (str): The title of the course.
        learning_outcomes (List[str]): A list of learning outcomes.

    Returns:
        str: A concise scenario for the case study.
    """
    
    # Retrieve the course title and bloom taxonomy level
    course_title = data.course_title
    bloom_taxonomy_level = data.tsc_proficiency_level

    # Extract the learning outcomes as a list of strings
    learning_outcomes = [lu.learning_outcome for lu in data.learning_units]
    abilities = [ability.text for lu in data.learning_units for topic in lu.topics for ability in topic.tsc_abilities]
    
    outcomes_text = "\n".join([f"- {lo}" for lo in learning_outcomes])
    abilities_text = "\n".join([f"- {ability}" for ability in abilities])

    prompt = (
        f"You are tasked with designing a concise, realistic case study scenario for the course '{course_title}'.\n\n"
        f"The scenario should align with the following:\n\n"
        f"Learning Outcomes:\n{outcomes_text}\n\n"
        f"Abilities:\n{abilities_text}\n\n"
        f"Bloom's Taxonomy Level:\n{bloom_taxonomy_level}\n\n"
        "The scenario should describe a company or organization facing challenges related to communication, collaboration, or customer satisfaction. "
        "Ensure the scenario is realistic and practical, and keep it to 1-2 paragraphs without markdown elements or formatting."
    )
    response = engine.query(prompt)
    return response.response.strip()

def retrieve_content_for_learning_outcomes(extracted_data, engine):
    """
    Retrieves content related to the learning outcomes and abilities from the provided data.

    Args:
        extracted_data (FacilitatorGuideExtraction): The extracted data instance containing course details.

    Returns:
        List[Dict]: A list of dictionaries containing retrieved content and associated abilities.
    """
    retrieved_content = []

    for learning_unit in extracted_data.learning_units:
        learning_outcome = learning_unit.learning_outcome
        associated_abilities = []
        ability_ids = []
        for topic in learning_unit.topics:
            associated_abilities.extend(topic.tsc_abilities)
            ability_ids.extend([ability.id for ability in topic.tsc_abilities])

        # Define the content retrieval prompt
        retrieval_prompt = (
            f"Retrieve the most relevant inline segments aligned to Learning Outcome: {learning_outcome}\n"
            f"Associated Abilities:\n"
            + "\n".join([f"- [{ability.id}] {ability.text}" for ability in associated_abilities])
            + f"\nFrom the given Topics: {', '.join([topic.name for topic in learning_unit.topics])}"
        )

        response = engine.query(retrieval_prompt)
        retrieved_content.append({
            "learning_outcome": learning_outcome,
            "abilities": ability_ids,
            "retrieved_content": response.response
        })
    
    return retrieved_content

# %%
from llama_index.llms.openai import OpenAI as llama_openai
from autogen import AssistantAgent, UserProxyAgent
from autogen.cache import Cache
import streamlit as st
import json
import re
import pprint

openai_api_key = llm_config["config_list"][0]["api_key"]
system_prompt = """\
You are an instructional design assistant tasked with generating concise, realistic, and practical scenario-based question-answer pairs for educational purposes.

Your role:
1. **Generate a real-world scenario** for the given Course Title and Learning Outcome (LO). The scenario must:
- Be concise (1-2 paragraphs) while clearly describing the organizational challenges or context.
- Align directly with the Learning Outcome and be applicable to the associated abilities.
- Highlight specific organizational data, challenges, and objectives to ensure relevance and practicality.

2. Use only the information relevant to the specified Learning Unit, Learning Outcome, and its abilities. Do not include information from unrelated topics.

3. Ensure that:
- Each scenario and question-answer pair is realistic, aligned to Bloom's Taxonomy level for the LO, and practically applicable.
- If no relevant content exists, create a general scenario that remains educationally valuable and tied to the broader course theme.

**Output Format:**
- Tase study scenario have to be at least 500 words long.
- You will output your response in the following format. For example:
TechFusion, a leading software solutions provider, has been approached by a global bank to develop a new mobile banking application. The bank wants to offer its customers a seamless, secure, and intuitive banking experience on their smartphones. Given the competitive landscape, the bank emphasizes the need for rapid delivery without compromising on quality. TechFusion has recently adopted Agile methodologies with Scrum and DevOps practices and sees this project as an opportunity to showcase its capabilities in these areas.

**Restrictions:**
- Do not include content from other topics or unrelated slides.
- Do not invent abilities or knowledge outside the scope of the LO and its associated abilities.
"""


scenario_llm = llama_openai(model="gpt-4o-mini", api_key=openai_api_key, system_prompt=system_prompt)

scenario_query_engine = index.as_query_engine(
    similarity_top_k=10,
    llm=scenario_llm,
    response_mode="compact",
)
# Generate the shared scenario
scenario = generate_case_study_scenario(extracted_data, scenario_query_engine)

system_prompt = """\
You are a content retrieval assistant. Your role is to retrieve topic content that aligns strictly with the specified Learning Outcome (LO) and its associated abilities.

Your role:
1. Restrict your retrieval strictly to the specified topic provided in the query.
2. Retrieve content from the topic that directly aligns with the provided Learning Outcome (LO) and its abilities.
3. If no specific content directly aligns with the Learning Outcome or abilities, provide a general summary of the topic instead.
4. Include any example/usecase code or equations relevant to the topic or subtopics.
5. Prioritize retrieving content that are practical.
6. Identify and extract the exact inline segments from the provided documents that directly correspond to the content used to generate the summary. The extracted segments must be verbatim snippets from the documents, ensuring a word-for-word match with the text in the provided documents.

Ensure that:
- (Important) Each retrieved segment is an exact match to a part of the document and is fully contained within the document text.
- The relevance of each segment to the Learning Outcome or abilities is clear and directly supports the summary provided.
- (Important) If you didn't use the specific document or topic, do not mention it.
- If no relevant information is found for the Learning Outcome, clearly state this and provide a general topic summary instead.

Restrictions:
- Do not include content from other topics or slides outside the specified topic.
- Each retrieved segment must explicitly belong to the given topic.
- Avoid including assumptions or content outside the scope of the Learning Outcome and abilities.

You must always provide:
1. The retrieved content aligned with the Learning Outcome and abilities.
2. A list of verbatim extracted segments that directly support the retrieved content, each labeled with the topic and document it belongs to.
"""

lo_retriever_llm = llama_openai(model="gpt-4o-mini", api_key=openai_api_key, system_prompt=system_prompt)
qa_generation_query_engine = index.as_query_engine(
    similarity_top_k=10,
    llm=lo_retriever_llm,
    response_mode="tree_summarize",
)
retrieved_content = retrieve_content_for_learning_outcomes(extracted_data, qa_generation_query_engine)

# %%
pprint.pprint(retrieved_content)
# Out:
# [{'abilities': ['A1'],
#   'learning_outcome': 'Develop project parameters with GenAI according to '
#                       'business requirements',
#   'retrieved_content': 'To align with the Learning Outcome of developing '
#                        'project parameters with GenAI according to business '
#                        'requirements, the following relevant content has been '
#                        'extracted:\n'
#                        '\n'
#                        '### Retrieved Content:\n'
#                        '1. **Develop Project Parameters**: The course '
#                        'emphasizes the importance of developing project '
#                        'parameters that align with business requirements. This '
#                        'includes creating a project charter, identifying '
#                        'stakeholders, and developing a project management plan '
#                        'that encompasses various management aspects such as '
#                        'scope, schedule, cost, quality, resources, and risks.\n'
#                        '\n'
#                        '2. **Project Charter**: The project charter is a '
#                        'critical document that authorizes the project and '
#                        'outlines the rationale and business need, ensuring '
#                        'alignment with strategic goals. It serves as a '
#                        'foundational element in developing project '
#                        'parameters.\n'
#                        '\n'
#                        '3. **Stakeholder Engagement**: Identifying and '
#                        'engaging stakeholders is essential for understanding '
#                        'business requirements and ensuring that the project '
#                        'parameters meet their needs.\n'
#                        '\n'
#                        '### Verbatim Extracted Segments:\n'
#                        '- "Develop Project Charter" - This is part of the '
#                        'project initiation process where the project '
#                        'parameters are defined.\n'
#                        '- "Defines rationale and business need" - This '
#                        'highlights the importance of aligning project '
#                        'parameters with business requirements.\n'
#                        '- "Identify Stakeholders" - This is crucial for '
#                        'understanding the business context and requirements.\n'
#                        '- "Develop Project Management Plan" - This includes '
#                        'planning for scope, schedule, cost, quality, '
#                        'resources, and risks, which are all project '
#                        'parameters.\n'
#                        '\n'
#                        '### Supporting Segments:\n'
#                        '- **Topic 1: Project Initiation and Planning with '
#                        'GenAI**:\n'
#                        '  - "Develop Project Charter"\n'
#                        '  - "Identify Stakeholders"\n'
#                        '  - "Develop Project Management Plan"\n'
#                        '\n'
#                        '- **Learning Outcomes**:\n'
#                        '  - "By the end of the course, learners will be able '
#                        'to develop project parameters with GenAI according to '
#                        'business requirements."\n'
#                        '\n'
#                        'These segments collectively support the ability to '
#                        'develop project parameters in alignment with business '
#                        'requirements using Generative AI.'},
#  {'abilities': ['A2'],
#   'learning_outcome': 'Resolve project delivery challenges by optimizing '
#                       'resource and project budgets with GenAI.',
#   'retrieved_content': 'To address the Learning Outcome of resolving project '
#                        'delivery challenges by optimizing resource and project '
#                        'budgets with GenAI, the following relevant content has '
#                        'been extracted:\n'
#                        '\n'
#                        '1. **Project Execution and Delivery with GenAI**:\n'
#                        '   - This topic emphasizes the importance of managing '
#                        'resources effectively to ensure successful project '
#                        'delivery. It includes strategies for optimizing '
#                        'resource allocation and budget management, which are '
#                        'crucial for overcoming delivery challenges.\n'
#                        '\n'
#                        '2. **Key Points**:\n'
#                        '   - **Manage Project Knowledge**: This involves '
#                        'leveraging knowledge management techniques to ensure '
#                        'that all team members are aware of the resources '
#                        'available and how to utilize them effectively.\n'
#                        '   - **Manage Stakeholder Engagement**: Engaging '
#                        'stakeholders effectively can help in identifying '
#                        'resource needs and budget constraints, allowing for '
#                        'better planning and execution.\n'
#                        '   - **Acquire Resources**: This process focuses on '
#                        'ensuring that the right resources are available when '
#                        'needed, which is essential for maintaining project '
#                        'timelines and budgets.\n'
#                        '   - **Manage Team**: Effective team management '
#                        'ensures that all members are aligned with project '
#                        'goals and can contribute to resolving challenges as '
#                        'they arise.\n'
#                        '\n'
#                        '3. **Practical Techniques**:\n'
#                        '   - **Resource Optimization**: Techniques such as '
#                        'resource leveling and smoothing can be employed to '
#                        'ensure that resources are utilized efficiently without '
#                        'overloading team members.\n'
#                        '   - **Cost Management**: Implementing a robust cost '
#                        'management plan that includes estimating costs '
#                        'accurately and monitoring expenditures against the '
#                        'budget can help in identifying potential overruns '
#                        'early.\n'
#                        '\n'
#                        '### Extracted Segments:\n'
#                        '1. **Manage Project Knowledge**:\n'
#                        '   - "This involves leveraging knowledge management '
#                        'techniques to ensure that all team members are aware '
#                        'of the resources available and how to utilize them '
#                        'effectively."\n'
#                        '\n'
#                        '2. **Acquire Resources**:\n'
#                        '   - "This process focuses on ensuring that the right '
#                        'resources are available when needed, which is '
#                        'essential for maintaining project timelines and '
#                        'budgets."\n'
#                        '\n'
#                        '3. **Manage Team**:\n'
#                        '   - "Effective team management ensures that all '
#                        'members are aligned with project goals and can '
#                        'contribute to resolving challenges as they arise."\n'
#                        '\n'
#                        '4. **Resource Optimization**:\n'
#                        '   - "Techniques such as resource leveling and '
#                        'smoothing can be employed to ensure that resources are '
#                        'utilized efficiently without overloading team '
#                        'members."\n'
#                        '\n'
#                        '5. **Cost Management**:\n'
#                        '   - "Implementing a robust cost management plan that '
#                        'includes estimating costs accurately and monitoring '
#                        'expenditures against the budget can help in '
#                        'identifying potential overruns early."\n'
#                        '\n'
#                        'These segments collectively support the Learning '
#                        'Outcome by highlighting the importance of resource and '
#                        'budget optimization in resolving project delivery '
#                        'challenges using GenAI.'},
#  {'abilities': ['A3', 'A4'],
#   'learning_outcome': 'Anticipate and devise risk mitigation measures with '
#                       'GenAI to ensure project success',
#   'retrieved_content': 'To address the Learning Outcome of anticipating and '
#                        'devising risk mitigation measures with GenAI to ensure '
#                        'project success, the following relevant content has '
#                        'been extracted:\n'
#                        '\n'
#                        '1. **Anticipating Risks**:\n'
#                        '   - "Risk originates from a wide range of known and '
#                        'unknown causes within and outside the business '
#                        'environment."\n'
#                        '   - "Risk development is indicated by a trigger '
#                        'condition."\n'
#                        '   - "Risks can be positive (opportunities) or '
#                        'negative (threats)."\n'
#                        '\n'
#                        '2. **Risk Management Process**:\n'
#                        '   - "Identify Risks: The process of determining which '
#                        'risks may affect the project and documenting their '
#                        'characteristics."\n'
#                        '   - "Perform Qualitative Risk Analysis: This involves '
#                        'assessing the impact and likelihood of identified '
#                        'risks."\n'
#                        '   - "Plan Risk Responses: A trigger condition signals '
#                        'a risk can develop. Team implements a risk response."\n'
#                        '\n'
#                        '3. **Risk Mitigation Measures**:\n'
#                        '   - "Mitigate: An action to reduce the probability or '
#                        'impact of the threat."\n'
#                        '   - "Accept: Acknowledges the threat; but takes no '
#                        'action."\n'
#                        '   - "Transfer: Shifting ownership of the threat to a '
#                        'third party, often for a fee (i.e., insurance)."\n'
#                        '   - "Exploit: We ensure the opportunity happens '
#                        '(i.e., assigning resources to it, prioritizing it)."\n'
#                        '\n'
#                        '4. **Monitoring Risks**:\n'
#                        '   - "Continuously monitor status, probability and '
#                        'impact."\n'
#                        '   - "Identify new risks."\n'
#                        '   - "Reassess current risks."\n'
#                        '\n'
#                        '### Extracted Segments:\n'
#                        '- **From "Manage Project Risks with GenAI"**:\n'
#                        '  - "Risk originates from a wide range of known and '
#                        'unknown causes within and outside the business '
#                        'environment."\n'
#                        '  - "Risk development is indicated by a trigger '
#                        'condition."\n'
#                        '  - "Risks can be positive (opportunities) or negative '
#                        '(threats)."\n'
#                        '  - "Identify Risks: The process of determining which '
#                        'risks may affect the project and documenting their '
#                        'characteristics."\n'
#                        '  - "Perform Qualitative Risk Analysis: This involves '
#                        'assessing the impact and likelihood of identified '
#                        'risks."\n'
#                        '  - "Plan Risk Responses: A trigger condition signals '
#                        'a risk can develop. Team implements a risk response."\n'
#                        '  - "Mitigate: An action to reduce the probability or '
#                        'impact of the threat."\n'
#                        '  - "Accept: Acknowledges the threat; but takes no '
#                        'action."\n'
#                        '  - "Transfer: Shifting ownership of the threat to a '
#                        'third party, often for a fee (i.e., insurance)."\n'
#                        '  - "Exploit: We ensure the opportunity happens (i.e., '
#                        'assigning resources to it, prioritizing it)."\n'
#                        '  - "Continuously monitor status, probability and '
#                        'impact."\n'
#                        '  - "Identify new risks."\n'
#                        '  - "Reassess current risks."\n'
#                        '\n'
#                        'These segments provide a comprehensive overview of how '
#                        'to anticipate risks and devise mitigation strategies '
#                        'using GenAI, aligning with the specified Learning '
#                        'Outcome and associated abilities.'}]

# %%
import json

llm_config={
    "config_list": [
        {
            'model': "gpt-4o",
            'api_key': OPENAI_API_KEY,
        },
    ],
    "timeout": 300,
}

user_proxy_agent = UserProxyAgent(
    name="user_proxy",
    human_input_mode="NEVER",
    max_consecutive_auto_reply=5,
    is_termination_msg=lambda msg: msg.get("content", "") and "TERMINATE" in msg["content"],
    code_execution_config={"work_dir": "output", "use_docker": False}
)

# Autogen setup
qa_generation_agent = AssistantAgent(
    name="question_answer_generator",
    system_message=f"""
    You are an expert educator in '{extracted_data.course_title}'. You will create scenario-based case study question-answer pairs based on course data.
    The data will include:
    - A scenario
    - Retrieved content aligned with learning outcomes and abilities

    ### Instructions:
    1. Use the provided scenario and retrieved content to generate one question-and-answer pairs per one learning outcome.
    2. Each question should be aligned with the learning outcome and abilities implied by the retrieved content and the Bloom's Taxonomy Level.
    3. The answer should demonstrate mastery of the abilities and address the scenario context.
    4. The **answer** must be in a **case study solution style**: a detailed solution or approach addressing the scenario's key challenges.
        - Explain what to do, why it matters, and any recommended tools or methods.
        - Provide a short rationale (“why”) for each recommended action, tying it back to the scenario’s goals.

    4. Ensure all keys and values are double-quoted in the JSON string output.
    5. Return the output in JSON in String format with the following structure:
    import
        ```
        {{
            "course_title": "<course_title_here>",
            "duration": "<assessment_duration_here>",
            "scenario": "<scenario_here>",
            "questions": [
            {{
                "question_statement": "<question_text>",
                "answer": "[<list_of_answer_text>]",
                "ability_id": ["<list_of_ability_ids>"]
            }},
            ...
            ]
        }}
        ```
    """,
    llm_config=llm_config,
)
assessment_duration = ""
for assessment in extracted_data.assessments:
    if "CS" in assessment.code:
        assessment_duration = assessment.duration

cs_context = {}
chat_result = user_proxy_agent.initiate_chat(
    qa_generation_agent,
    message=f"""
    Please generate the questions and answer using the following course title:'{extracted_data.course_title}', assessment_duration:'{assessment_duration}', scenario: '{scenario}' and topic contents:{retrieved_content}
    Phrase your question in accordance with the Bloom's Taxonomy Level: {extracted_data.tsc_proficiency_level}
    Bloom's Taxonomy Level Information:
        Level 1: Remembering
        Level 2: Understanding
        Level 3: Applying
        Level 4: Analyzing
        Level 5: Evaluating
        Level 6: Creating
    Return the question and answer as a JSON in String Format containing the specified fields.
    import
    ```
    {{
        "course_title": "<course_title_here>",
        "duration": "<assessment_duration_here>",
        "scenario": "<scenario_here>",
        "questions": [
        {{
            "question_statement": "<question_text>",
            "answer": "[<list_of_answer_text>]",
            "ability_id": ["<list_of_ability_ids>"]
        }},
        ...
        ]
    }}
    ```
    RETURN 'TERMINATE' once the generation is done.
    """,
    summary_method="reflection_with_llm",
)
try:
    last_message_content = chat_result.chat_history[-1].get("content", "")
    if not last_message_content:
        print("No content found in the agent's last message.")
    last_message_content = last_message_content.strip()
    json_pattern = re.compile(r'```json\s*(\{.*?\})\s*```', re.DOTALL)
    json_match = json_pattern.search(last_message_content)
    if json_match:
        json_str = json_match.group(1)
        context = json.loads(json_str)
        cs_context = context
        pprint.pprint(context)
    pprint.pprint(f"CS cost: {chat_result.cost}")
except json.JSONDecodeError as e:
    print(f"Error parsing context JSON: {e}")
# Out:
# [autogen.oai.client: 12-24 13:17:12] {164} WARNING - The API key specified is not a valid OpenAI format; it won't work with the OpenAI-hosted model.
# user_proxy (to question_answer_generator):
#
#
#     Please generate the questions and answer using the following course title:'Project Management with Generative AI (GenAI)', assessment_duration:'1 hr', scenario: 'TechSolutions, a mid-sized IT consulting firm, has recently adopted Generative AI (GenAI) to enhance its project management capabilities. However, the company is struggling with communication breakdowns between project teams and clients, leading to misaligned expectations and delayed deliverables. As a result, customer satisfaction has plummeted, and project budgets are being exceeded due to rework and inefficient resource allocation. The management team recognizes the need to develop clear project parameters that align with client requirements and to optimize resource usage through GenAI tools. They also aim to identify potential risks associated with project delivery and implement effective risk mitigation strategies to ensure successful project outcomes.
#
# In this context, the project manager is tasked with leveraging GenAI to establish precise project parameters that reflect business needs, advising team members on overcoming delivery challenges, and proactively identifying risks that could impact project timelines and budgets. By utilizing GenAI, the manager seeks to create a more collaborative environment, streamline communication, and enhance overall project efficiency, ultimately restoring client trust and satisfaction.' and topic contents:[{'learning_outcome': 'Develop project parameters with GenAI according to business requirements', 'abilities': ['A1'], 'retrieved_content': 'To align with the Learning Outcome of developing project parameters with GenAI according to business requirements, the following relevant content has been extracted:\n\n### Retrieved Content:\n1. **Develop Project Parameters**: The course emphasizes the importance of developing project parameters that align with business requirements. This includes creating a project charter, identifying stakeholders, and developing a project management plan that encompasses various management aspects such as scope, schedule, cost, quality, resources, and risks.\n\n2. **Project Charter**: The project charter is a critical document that authorizes the project and outlines the rationale and business need, ensuring alignment with strategic goals. It serves as a foundational element in developing project parameters.\n\n3. **Stakeholder Engagement**: Identifying and engaging stakeholders is essential for understanding business requirements and ensuring that the project parameters meet their needs.\n\n### Verbatim Extracted Segments:\n- "Develop Project Charter" - This is part of the project initiation process where the project parameters are defined.\n- "Defines rationale and business need" - This highlights the importance of aligning project parameters with business requirements.\n- "Identify Stakeholders" - This is crucial for understanding the business context and requirements.\n- "Develop Project Management Plan" - This includes planning for scope, schedule, cost, quality, resources, and risks, which are all project parameters.\n\n### Supporting Segments:\n- **Topic 1: Project Initiation and Planning with GenAI**:\n  - "Develop Project Charter"\n  - "Identify Stakeholders"\n  - "Develop Project Management Plan"\n\n- **Learning Outcomes**:\n  - "By the end of the course, learners will be able to develop project parameters with GenAI according to business requirements."\n\nThese segments collectively support the ability to develop project parameters in alignment with business requirements using Generative AI.'}, {'learning_outcome': 'Resolve project delivery challenges by optimizing resource and project budgets with GenAI.', 'abilities': ['A2'], 'retrieved_content': 'To address the Learning Outcome of resolving project delivery challenges by optimizing resource and project budgets with GenAI, the following relevant content has been extracted:\n\n1. **Project Execution and Delivery with GenAI**:\n   - This topic emphasizes the importance of managing resources effectively to ensure successful project delivery. It includes strategies for optimizing resource allocation and budget management, which are crucial for overcoming delivery challenges.\n\n2. **Key Points**:\n   - **Manage Project Knowledge**: This involves leveraging knowledge management techniques to ensure that all team members are aware of the resources available and how to utilize them effectively.\n   - **Manage Stakeholder Engagement**: Engaging stakeholders effectively can help in identifying resource needs and budget constraints, allowing for better planning and execution.\n   - **Acquire Resources**: This process focuses on ensuring that the right resources are available when needed, which is essential for maintaining project timelines and budgets.\n   - **Manage Team**: Effective team management ensures that all members are aligned with project goals and  ...
#     Phrase your question in accordance with the Bloom's Taxonomy Level: 5
#     Bloom's Taxonomy Level Information:
#         Level 1: Remembering
#         Level 2: Understanding
#         Level 3: Applying
#         Level 4: Analyzing
#         Level 5: Evaluating
#         Level 6: Creating
#     Return the question and answer as a JSON in String Format containing the specified fields.
#     import
#     ```
#     {
#         "course_title": "<course_title_here>",
#         "duration": "<assessment_duration_here>",
#         "scenario": "<scenario_here>",
#         "questions": [
#         {
#             "question_statement": "<question_text>",
#             "answer": "[<list_of_answer_text>]",
#             "ability_id": ["<list_of_ability_ids>"]
#         },
#         ...
#         ]
#     }
#     ```
#     RETURN 'TERMINATE' once the generation is done.
#
#
# --------------------------------------------------------------------------------
# question_answer_generator (to user_proxy):
#
# ```json
# {
#     "course_title": "Project Management with Generative AI (GenAI)",
#     "duration": "1 hr",
#     "scenario": "TechSolutions, a mid-sized IT consulting firm, has recently adopted Generative AI (GenAI) to enhance its project management capabilities. However, the company is struggling with communication breakdowns between project teams and clients, leading to misaligned expectations and delayed deliverables. As a result, customer satisfaction has plummeted, and project budgets are being exceeded due to rework and inefficient resource allocation. The management team recognizes the need to develop clear project parameters that align with client requirements and to optimize resource usage through GenAI tools. They also aim to identify potential risks associated with project delivery and implement effective risk mitigation strategies to ensure successful project outcomes. In this context, the project manager is tasked with leveraging GenAI to establish precise project parameters that reflect business needs, advising team members on overcoming delivery challenges, and proactively identifying risks that could impact project timelines and budgets. By utilizing GenAI, the manager seeks to create a more collaborative environment, streamline communication, and enhance overall project efficiency, ultimately restoring client trust and satisfaction.",
#     "questions": [
#         {
#             "question_statement": "Evaluate how TechSolutions can develop project parameters using Generative AI to ensure they align with business requirements.",
#             "answer": [
#                 "To develop project parameters that align with the business requirements using Generative AI, TechSolutions should first ensure the creation of a comprehensive Project Charter. This foundational document serves to clearly outline the project's objectives, scope, and the business rationale, aligning with strategic goals.",
#                 "Next, TechSolutions should engage key stakeholders, both internal and external, to gain a holistic understanding of the business requirements. This can be achieved by utilizing GenAI tools to analyze stakeholder inputs and generate insights on expectations and constraints.",
#                 "Subsequently, TechSolutions should leverage Generative AI to develop a Project Management Plan encompassing scope, schedule, cost, quality, and resources. GenAI can help model different scenarios to find the optimal set of project parameters that meet business requirements while maximizing efficiency.",
#                 "It's important to continuously update and refine these parameters as the project progresses and new information becomes available, using GenAI's predictive analytics capabilities to anticipate changes and adjust plans proactively.",
#                 "Aligning project parameters with genuine business needs is crucial as it ensures that the project delivers value to the organization and meets stakeholders' expectations, thereby restoring client trust and satisfaction."
#             ],
#             "ability_id": ["A1"]
#         },
#         {
#             "question_statement": "Evaluate strategies that TechSolutions can use to resolve project delivery challenges and optimize resources and budgets with Generative AI.",
#             "answer": [
#                 "TechSolutions can address project delivery challenges by implementing Generative AI-driven strategies for optimizing resource allocation and budget management. Firstly, the firm should enhance knowledge management to ensure all team members are aware of the available resources and how to leverage them effectively. This involves creating a centralized knowledge repository with GenAI to provide insights on resource utilization and availability.",
#                 "Leveraging GenAI for resource optimization techniques such as resource leveling and smoothing can minimize overload and ensure that resources are efficiently allocated based on real-time demands. This is essential for maintaining productivity without exhausting the team.",
#                 "Cost management is another critical area, where TechSolutions can employ GenAI to produce accurate cost estimates and continuously monitor actual expenditures against the budget. This allows for early detection of potential overruns and deviations, facilitating proactive adjustments.",
#                 "Furthermore, by engaging stakeholders through AI-driven communication tools, TechSolutions can better understand resource needs and budget constraints, allowing for informed decision-making and alignment with project goals.",
#                 "Optimizing resource allocation and managing budgets efficiently is key to overcoming project delivery challenges, reducing delays, and preventing budget overruns, ultimately contributing to successful project outcomes and enhanced customer satisfaction."
#             ],
#             "ability_id": ["A2"]
#         },
#         {
#             "question_statement": "Evaluate how TechSolutions can anticipate project risks and devise effective mitigation strategies using Generative AI.",
#             "answer": [
#                 "TechSolutions can anticipate project risks and devise mitigation strategies by using Generative AI to monitor for risk trigger conditions and predict potential impacts. GenAI can parse through vast volumes of data to identify both known and unknown risk factors, providing early warning signals.",
#                 "The company should implement a robust risk management process starting with the identification and documentation of potential risks. Generative AI can aid in creating a comprehensive risk register by analyzing historical project data and current project dynamics.",
#                 "Performing qualitative risk analysis using AI can help assess the likelihood and impact of each identified risk, allowing TechSolutions to prioritize risks based on their severity. GenAI can simulate different scenarios to evaluate how varying risk conditions might affect project delivery.",
#                 "In terms of risk responses, TechSolutions can use GenAI to develop strategic mitigation actions such as transferring risks, exploiting opportunities, or reducing the probability of threats. AI-enabled predictive models can test different mitigation strategies to choose the most effective responses.",
#                 "Continuous risk monitoring is essential, and Generative AI can automate this process by tracking risk statuses and identifying new risks as projects evolve. This proactive approach ensures that TechSolutions remains agile in its risk management, thereby safeguarding project outcomes and maintaining client confidence."
#             ],
#             "ability_id": ["A3", "A4"]
#         }
#     ]
# }
# ```
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING CODE BLOCK 0 (inferred language is json)...
# user_proxy (to question_answer_generator):
#
# exitcode: 1 (execution failed)
# Code output:
# unknown language json
#
# --------------------------------------------------------------------------------
# question_answer_generator (to user_proxy):
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# ("CS cost: {'usage_including_cached_inference': {'total_cost': 0.0345125, "
#  "'gpt-4o-2024-08-06': {'cost': 0.0345125, 'prompt_tokens': 9053, "
#  "'completion_tokens': 1188, 'total_tokens': 10241}}, "
#  "'usage_excluding_cached_inference': {'total_cost': 0.0345125, "
#  "'gpt-4o-2024-08-06': {'cost': 0.0345125, 'prompt_tokens': 9053, "
#  "'completion_tokens': 1188, 'total_tokens': 10241}}}")

# %%
import os
import tempfile
from docxtpl import DocxTemplate

def _ensure_list(answer):
    """
    Returns a list regardless of whether 'answer' is originally a list, string, or None.
    """
    if isinstance(answer, list):
        return answer
    elif isinstance(answer, str):
        # Wrap the string in a list so Jinja loops or docxtpl loops won't break
        return [answer]
    return []

def generate_documents(context: dict, assessment_type: str, output_dir: str) -> dict:
    """
    Generate the question paper and answer paper for the given context and type.

    Parameters:
    - context (dict): The data for the assessment (course title, type, questions, etc.).
    - assessment_type (str): The assessment type (e.g., 'Ability-based', 'Knowledge-based').
    - output_dir (str): Directory where the generated documents will be saved.

    Returns:
    - dict: Paths to the generated documents (question and answer papers).
    """

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Load template paths
    TEMPLATES = {
        "QUESTION": f"C:/Users/dljh1/Documents/courseware_autogen/Assessment/Templates/(Template) {assessment_type} - Course Title - v1.docx",
        "ANSWER": f"C:/Users/dljh1/Documents/courseware_autogen/Assessment/Templates/(Template) Answer to {assessment_type} - Course Title - v1.docx"
    }

    qn_template = TEMPLATES["QUESTION"]
    ans_template = TEMPLATES["ANSWER"]

    question_doc = DocxTemplate(qn_template)
    answer_doc = DocxTemplate(ans_template)
    
    # Prepare context for the answer paper:
    # Convert each question's 'answer' to a list if it's a string or None
    answer_context = {
        **context,
        "questions": [
            {
                **question,
                "answer": _ensure_list(question.get("answer"))
            }
            for question in context.get("questions", [])
        ]
    }

    # Prepare context for the question paper by creating a copy of the context without answers
    question_context = {
        **context,
        "questions": [
            {
                **question,
                "answer": None  # Remove answers for the question doc
            }
            for question in context.get("questions", [])
        ]
    }

    # Render both templates
    # IMPORTANT FIX: Use answer_context instead of context for the answer doc
    answer_doc.render(answer_context)
    question_doc.render(question_context)

    # Create temporary files for the question and answer documents
    question_tempfile = tempfile.NamedTemporaryFile(
        delete=False, suffix=f"_{assessment_type} - {context.get('course_title')} - v1.docx"
    )
    answer_tempfile = tempfile.NamedTemporaryFile(
        delete=False, suffix=f"Answer to {assessment_type} - {context.get('course_title')} - v1.docx"
    )

    # Save the rendered documents to the temporary files
    question_doc.save(question_tempfile.name)
    answer_doc.save(answer_tempfile.name)

    return {
        "ASSESSMENT_TYPE": assessment_type,
        "QUESTION": question_tempfile.name,
        "ANSWER": answer_tempfile.name
    }

# %%
cs_context = {
    "course_title": "Project Management with Generative AI (GenAI)",
    "duration": "1 hr",
    "scenario": "TechSolutions, a mid-sized IT consulting firm, has recently adopted Generative AI (GenAI) to enhance its project management capabilities. However, the company is struggling with communication breakdowns between project teams and clients, leading to misaligned expectations and delayed deliverables. As a result, customer satisfaction has plummeted, and project budgets are being exceeded due to rework and inefficient resource allocation. The management team recognizes the need to develop clear project parameters that align with client requirements and to optimize resource usage through GenAI tools. They also aim to identify potential risks associated with project delivery and implement effective risk mitigation strategies to ensure successful project outcomes. In this context, the project manager is tasked with leveraging GenAI to establish precise project parameters that reflect business needs, advising team members on overcoming delivery challenges, and proactively identifying risks that could impact project timelines and budgets. By utilizing GenAI, the manager seeks to create a more collaborative environment, streamline communication, and enhance overall project efficiency, ultimately restoring client trust and satisfaction.",
    "questions": [
        {
            "question_statement": "Evaluate how TechSolutions can develop project parameters using Generative AI to ensure they align with business requirements.",
            "answer": [
                "To develop project parameters that align with the business requirements using Generative AI, TechSolutions should first ensure the creation of a comprehensive Project Charter. This foundational document serves to clearly outline the project's objectives, scope, and the business rationale, aligning with strategic goals.",
                "Next, TechSolutions should engage key stakeholders, both internal and external, to gain a holistic understanding of the business requirements. This can be achieved by utilizing GenAI tools to analyze stakeholder inputs and generate insights on expectations and constraints.",
                "Subsequently, TechSolutions should leverage Generative AI to develop a Project Management Plan encompassing scope, schedule, cost, quality, and resources. GenAI can help model different scenarios to find the optimal set of project parameters that meet business requirements while maximizing efficiency.",
                "It's important to continuously update and refine these parameters as the project progresses and new information becomes available, using GenAI's predictive analytics capabilities to anticipate changes and adjust plans proactively.",
                "Aligning project parameters with genuine business needs is crucial as it ensures that the project delivers value to the organization and meets stakeholders' expectations, thereby restoring client trust and satisfaction."
            ],
            "ability_id": ["A1"]
        },
        {
            "question_statement": "Evaluate strategies that TechSolutions can use to resolve project delivery challenges and optimize resources and budgets with Generative AI.",
            "answer": [
                "TechSolutions can address project delivery challenges by implementing Generative AI-driven strategies for optimizing resource allocation and budget management. Firstly, the firm should enhance knowledge management to ensure all team members are aware of the available resources and how to leverage them effectively. This involves creating a centralized knowledge repository with GenAI to provide insights on resource utilization and availability.",
                "Leveraging GenAI for resource optimization techniques such as resource leveling and smoothing can minimize overload and ensure that resources are efficiently allocated based on real-time demands. This is essential for maintaining productivity without exhausting the team.",
                "Cost management is another critical area, where TechSolutions can employ GenAI to produce accurate cost estimates and continuously monitor actual expenditures against the budget. This allows for early detection of potential overruns and deviations, facilitating proactive adjustments.",
                "Furthermore, by engaging stakeholders through AI-driven communication tools, TechSolutions can better understand resource needs and budget constraints, allowing for informed decision-making and alignment with project goals.",
                "Optimizing resource allocation and managing budgets efficiently is key to overcoming project delivery challenges, reducing delays, and preventing budget overruns, ultimately contributing to successful project outcomes and enhanced customer satisfaction."
            ],
            "ability_id": ["A2"]
        },
        {
            "question_statement": "Evaluate how TechSolutions can anticipate project risks and devise effective mitigation strategies using Generative AI.",
            "answer": [
                "TechSolutions can anticipate project risks and devise mitigation strategies by using Generative AI to monitor for risk trigger conditions and predict potential impacts. GenAI can parse through vast volumes of data to identify both known and unknown risk factors, providing early warning signals.",
                "The company should implement a robust risk management process starting with the identification and documentation of potential risks. Generative AI can aid in creating a comprehensive risk register by analyzing historical project data and current project dynamics.",
                "Performing qualitative risk analysis using AI can help assess the likelihood and impact of each identified risk, allowing TechSolutions to prioritize risks based on their severity. GenAI can simulate different scenarios to evaluate how varying risk conditions might affect project delivery.",
                "In terms of risk responses, TechSolutions can use GenAI to develop strategic mitigation actions such as transferring risks, exploiting opportunities, or reducing the probability of threats. AI-enabled predictive models can test different mitigation strategies to choose the most effective responses.",
                "Continuous risk monitoring is essential, and Generative AI can automate this process by tracking risk statuses and identifying new risks as projects evolve. This proactive approach ensures that TechSolutions remains agile in its risk management, thereby safeguarding project outcomes and maintaining client confidence."
            ],
            "ability_id": ["A3", "A4"]
        }
    ]
}

files = generate_documents(
    context=cs_context, 
    assessment_type="CS",
    output_dir="output"
)

print(f"Generated documents: {files}")
# Out:
# Generated documents: {'ASSESSMENT_TYPE': 'CS', 'QUESTION': 'C:\\Users\\dljh1\\AppData\\Local\\Temp\\tmp153jv4mg_CS - Project Management with Generative AI (GenAI) - v1.docx', 'ANSWER': 'C:\\Users\\dljh1\\AppData\\Local\\Temp\\tmpro13zz9bAnswer to CS - Project Management with Generative AI (GenAI) - v1.docx'}
